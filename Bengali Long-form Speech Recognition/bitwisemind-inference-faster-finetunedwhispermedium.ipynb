# %% [markdown]
# # DEPENDENCY INSTALLATION

# %%
# !pip install -q "transformers>=4.35.0" "accelerate>=0.24.0"
# !pip install -q torch torchaudio sentencepiece protobuf pandas
# !pip install -q faster-whisper ctranslate2 huggingface_hub librosa

print("✅ Dependencies installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 43.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 77.5 MB/s eta 0:00:00
# ✅ Dependencies installed.

# %% [markdown]
# # IMPORTS

# %%
import gc
import os
import re
import time
import unicodedata
import warnings
import threading
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Tuple
from zoneinfo import ZoneInfo

import ctranslate2
import librosa
import numpy as np
import pandas as pd
import torch
import torchaudio
import transformers
from huggingface_hub import login
from tqdm.auto import tqdm
from transformers import WhisperForConditionalGeneration, WhisperProcessor

warnings.filterwarnings("ignore")
print("✅ Imports ready.")
# Out:
# ✅ Imports ready.

# %% [markdown]
# # CONFIGURATION
# - All runtime parameters are defined here. Edit before running.

# %%
# ── HuggingFace Model ─────────────────────────────────────────────────────────
HF_MODEL_ID       = "bitwisemind/sam_15000_clean_text_full_model"
HF_TOKEN          = "API_KEY"          # paste your token here if the model is private

# ── CTranslate2 Model ─────────────────────────────────────────────────────────
CT2_MODEL_DIR     = "whisper-tiny-ct2"   # local output dir of ct2-transformers-converter

# ── Paths ─────────────────────────────────────────────────────────────────────
AUDIO_BASE_PATH   = (
    "/kaggle/input/competitions/"
    "dl-sprint-4-0-bengali-long-form-speech-recognition/"
    "transcription/transcription/test/audio"
)
OUTPUT_CSV        = "/kaggle/working/transcriptions_ct2.csv"

# ── Chunking & Batching ───────────────────────────────────────────────────────
CHUNK_S           = 25    # audio chunk length in seconds
OVERLAP_S         = 0     # overlap between chunks in seconds
BATCH_SIZE        = 8     # chunks per GPU per batch

# ── Multi-GPU ─────────────────────────────────────────────────────────────────
NUM_GPUS          = 2     # number of CUDA GPUs to use

# ── Device ────────────────────────────────────────────────────────────────────
DEVICE            = "cuda" if torch.cuda.is_available() else "cpu"

print("✅ Configuration loaded.")
print(f"   HF Model      : {HF_MODEL_ID}")
print(f"   CT2 Model Dir : {CT2_MODEL_DIR}")
print(f"   Device        : {DEVICE}")
print(f"   GPUs          : {NUM_GPUS}  |  Chunk: {CHUNK_S}s  |  Batch: {BATCH_SIZE}")
print(f"   Output CSV    : {OUTPUT_CSV}")
# Out:
# ✅ Configuration loaded.
#    HF Model      : bitwisemind/sam_15000_clean_text_full_model
#    CT2 Model Dir : whisper-tiny-ct2
#    Device        : cuda
#    GPUs          : 2  |  Chunk: 25s  |  Batch: 8
#    Output CSV    : /kaggle/working/transcriptions_ct2.csv

# %% [markdown]
# # AUDIO UTILITIES

# %%
def format_time(seconds: float) -> str:
    """Convert a duration in seconds to a human-readable h/m/s string."""
    h, rem = divmod(int(seconds), 3600)
    m, s   = divmod(rem, 60)
    if h > 0: return f"{h}h {m}m {s}s"
    if m > 0: return f"{m}m {s}s"
    return f"{s}s"


def load_audio(path: str) -> np.ndarray:
    """Load an audio file as a mono 16 kHz float32 numpy array."""
    audio, _ = librosa.load(path, sr=16000, mono=True)
    return audio


def make_chunks(audio: np.ndarray, chunk_s: int = CHUNK_S,
                overlap_s: int = OVERLAP_S) -> List[np.ndarray]:
    """Split audio into fixed-length chunks; pad the last one if needed."""
    chunk_size    = chunk_s   * 16000
    overlap_size  = overlap_s * 16000
    stride        = chunk_size - overlap_size
    chunks, start = [], 0

    while start < len(audio):
        end   = min(start + chunk_size, len(audio))
        chunk = audio[start:end]
        if len(chunk) < chunk_size:
            chunk = np.pad(chunk, (0, chunk_size - len(chunk)))
        chunks.append(chunk)
        if end >= len(audio):
            break
        start += stride

    return chunks


def merge_transcriptions(transcriptions: List[str]) -> str:
    """Join per-chunk transcriptions into a single string, collapsing whitespace."""
    if not transcriptions:
        return ""
    return " ".join(" ".join(transcriptions).split())


def validate_audio_files(
    audio_files: List[str], base_path: str
) -> Tuple[List[Path], List[str]]:
    """Check which requested audio files exist on disk."""
    base = Path(base_path)
    valid, missing = [], []
    for f in audio_files:
        p = base / f
        (valid if p.exists() else missing).append(p if p.exists() else f)
    return valid, missing


print("✅ Audio utilities ready.")
# Out:
# ✅ Audio utilities ready.

# %% [markdown]
# # TEXT NORMALIZATION & POST-PROCESSING

# %%
# Zero-width Unicode characters frequently introduced by Bengali ASR outputs
_ZW_PATTERN = re.compile(r"[\u200B-\u200D\uFEFF]")


def normalize_bn_text(text: str) -> str:
    """Normalize Bengali text: NFC unicode, remove zero-width chars, collapse spaces."""
    if not text:
        return ""
    text = unicodedata.normalize("NFC", str(text))
    text = _ZW_PATTERN.sub("", text)
    text = text.replace("\u00A0", " ")   # non-breaking space → regular space
    return " ".join(text.split())


def clean_transcript(text: str) -> str:
    """Remove ASR hallucination artifacts from a transcript.

    Handles three hallucination patterns common in Whisper outputs:
      1. Multi-word phrases repeated 3+ times in sequence.
      2. Single words repeated 3+ times in sequence.
      3. Character n-grams repeated without spaces (e.g., "হেহেহেহে").
    Also strips '>>' speaker-change markers.
    """
    if not text or (isinstance(text, float) and pd.isna(text)):
        return text

    text = str(text).replace(">>", "")

    for pattern, replacement in [
        (r"\b((?:\S+\s+){1,5}\S+)(?:\s+\1){2,}\b", r"\1"),   # repeated phrases
        (r"\b(\S+)(?:\s+\1){2,}\b",                 r"\1"),   # repeated words
        (r"(.{2,}?)\1{2,}",                          r"\1"),   # repeated char-grams
    ]:
        prev = None
        while prev != text:
            prev = text
            text = re.sub(pattern, replacement, text)

    return re.sub(r"\s+", " ", text).strip()


def normalize_and_postprocess(text: str) -> str:
    """Apply Unicode normalization then hallucination-removal to a transcript."""
    # return clean_transcript(normalize_bn_text(text))
    return normalize_bn_text(text)


print("✅ Text normalization utilities ready.")
# Out:
# ✅ Text normalization utilities ready.

# %% [markdown]
# # MULTI-GPU CTRANSLATE2 INFERENCE (2× GPU)
# - **Step 1** — Authenticate with HuggingFace (private models only).
# - **Step 2** — Convert HuggingFace model to CTranslate2 format (run once).
# - **Step 3** — Load processor, CT2 models, and Bengali prompt.
# - **Step 4** — Define inference engine functions.
# - **Step 5** — Run inference; normalization + post-processing applied per-chunk and on final merged output.

# %%
# Authenticate with HuggingFace (required only for private models)
if HF_TOKEN:
    login(token=HF_TOKEN)
    print("✅ Logged in to HuggingFace Hub.")
else:
    print("ℹ️  HF_TOKEN not set — skipping login (public models only).")
# Out:
# ✅ Logged in to HuggingFace Hub.

# %%
# Convert HuggingFace Whisper → CTranslate2 format (run once; skip if already done)
import os
if not os.path.isdir(CT2_MODEL_DIR):
    print(f"🔄 Converting {HF_MODEL_ID} → {CT2_MODEL_DIR} ...")
    os.system(
        f"ct2-transformers-converter "
        f"--model {HF_MODEL_ID} "
        f"--output_dir {CT2_MODEL_DIR} "
        f"--quantization float16"
    )
    print(f"✅ Conversion complete → {CT2_MODEL_DIR}")
else:
    print(f"✅ CT2 model already exists at '{CT2_MODEL_DIR}' — skipping conversion.")
# Out:
# 🔄 Converting bitwisemind/sam_15000_clean_text_full_model → whisper-tiny-ct2 ...
# Loading weights: 100%|██████████| 947/947 [00:01<00:00, 887.56it/s, Materializing param=model.encoder.layers.23.self_attn_layer_norm.weight]
# ✅ Conversion complete → whisper-tiny-ct2

# %%
torch.cuda.empty_cache(); gc.collect()

# ── Processor ─────────────────────────────────────────────────────────────────
print(f"📥 Loading WhisperProcessor : {HF_MODEL_ID}")
ct2_processor = WhisperProcessor.from_pretrained(HF_MODEL_ID)

# ── CTranslate2 models — one per GPU ──────────────────────────────────────────
print(f"📥 Loading CTranslate2 model on {NUM_GPUS} GPU(s) ...")
ct2_models = [
    ctranslate2.models.Whisper(
        CT2_MODEL_DIR,
        device       = "cuda",
        device_index = gpu_id,
        compute_type = "float16",
        inter_threads = 2,
        intra_threads = 4,
    )
    for gpu_id in range(NUM_GPUS)
]

# ── Bengali forced-decoder prompt ─────────────────────────────────────────────
BN_PROMPT = ct2_processor.tokenizer.convert_tokens_to_ids([
    "<|startoftranscript|>",
    "<|bn|>",
    "<|transcribe|>",
    "<|notimestamps|>",
])

print(f"✅ CT2 models ready on {NUM_GPUS} GPU(s).")
print(f"   Processor : {HF_MODEL_ID}")
print(f"   Prompt    : {BN_PROMPT}")
# Out:
# 📥 Loading WhisperProcessor : bitwisemind/sam_15000_clean_text_full_model
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# 📥 Loading CTranslate2 model on 2 GPU(s) ...
# ✅ CT2 models ready on 2 GPU(s).
#    Processor : bitwisemind/sam_15000_clean_text_full_model
#    Prompt    : [50258, 50302, 50359, 50363]

# %%
# ── Per-GPU worker ────────────────────────────────────────────────────────────
def process_chunks(
    gpu_id      : int,
    chunk_indices: List[int],
    chunks      : List[np.ndarray],
    results_dict: dict,
    lock        : threading.Lock,
) -> None:
    """
    Transcribe a subset of audio chunks on one GPU.
    Normalization + post-processing is applied to every decoded chunk
    before the result is stored.
    """
    model = ct2_models[gpu_id]

    for i in range(0, len(chunk_indices), BATCH_SIZE):
        batch_indices = chunk_indices[i : i + BATCH_SIZE]
        batch         = [chunks[j] for j in batch_indices]

        inputs   = ct2_processor(batch, return_tensors="np", sampling_rate=16000)
        features = ctranslate2.StorageView.from_array(inputs.input_features)
        outputs  = model.generate(features, [BN_PROMPT] * len(batch))

        for j, result in zip(batch_indices, outputs):
            raw_text   = ct2_processor.decode(
                result.sequences_ids[0], skip_special_tokens=True
            )
            clean_text = normalize_and_postprocess(raw_text)   # ← per-chunk
            with lock:
                results_dict[j] = clean_text
            print(f"[GPU {gpu_id}] Chunk {j + 1}/{len(chunks)}: {clean_text[:80]}...")


# ── Single-file pipeline ──────────────────────────────────────────────────────
def transcribe_file_ct2(audio_path: str) -> Dict:
    """
    End-to-end CTranslate2 pipeline for one audio file:
      load → chunk → parallel GPU inference (per-chunk normalisation)
      → ordered merge → final normalize & post-process → result dict.
    """
    name       = Path(audio_path).name
    start_time = time.time()

    audio      = load_audio(audio_path)
    chunks     = make_chunks(audio)
    duration_s = len(audio) / 16000
    print(f"   {name}  |  {format_time(duration_s)}  |  {len(chunks)} chunks")

    # Distribute chunk indices round-robin across GPUs
    all_indices = list(range(len(chunks)))
    gpu_indices = [all_indices[g::NUM_GPUS] for g in range(NUM_GPUS)]

    results_dict : Dict           = {}
    lock         : threading.Lock = threading.Lock()

    # Run all GPUs in parallel
    with ThreadPoolExecutor(max_workers=NUM_GPUS) as executor:
        futures = [
            executor.submit(
                process_chunks, gpu_id, gpu_indices[gpu_id],
                chunks, results_dict, lock
            )
            for gpu_id in range(NUM_GPUS)
        ]
        for f in futures:
            f.result()

    # Merge in original order, then apply final post-processing pass
    ordered_texts    = [results_dict[i] for i in range(len(chunks))]
    merged           = merge_transcriptions(ordered_texts)
    final_transcript = normalize_and_postprocess(merged)          # ← final pass

    elapsed = time.time() - start_time
    print(
        f"   ✓ Done in {format_time(elapsed)}  |  "
        f"speed {duration_s / elapsed:.2f}× realtime  |  "
        f"{len(final_transcript)} chars"
    )
    return {
        "filename"          : Path(audio_path).stem,
        "transcript"        : final_transcript,
        "duration_s"        : round(duration_s, 2),
        "num_chunks"        : len(chunks),
        "processing_time_s" : round(elapsed, 2),
        "audio_path"        : audio_path,
    }


# ── Multi-file runner ─────────────────────────────────────────────────────────
def run_ct2_inference(base_path: str, output_csv: str) -> pd.DataFrame:
    """
    Auto-discover all audio files in base_path, transcribe each one,
    write filename + transcript to CSV, and return the results DataFrame.
    """
    audio_paths = sorted(
        p for p in Path(base_path).iterdir()
        if p.suffix.lower() in (".wav", ".mp3", ".flac", ".ogg", ".m4a")
    )
    if not audio_paths:
        print("❌ No audio files found in:", base_path)
        return pd.DataFrame()

    print(f"   Found {len(audio_paths)} audio file(s) to process.")
    results, total_start = [], time.time()

    for idx, path in enumerate(audio_paths, 1):
        print(f"\n[{idx}/{len(audio_paths)}]")
        try:
            results.append(transcribe_file_ct2(str(path)))
        except Exception as exc:
            import traceback
            print(f"   ❌ Failed: {exc}")
            traceback.print_exc()
            results.append({
                "filename"          : path.stem,
                "transcript"        : f"[ERROR: {exc}]",
                "duration_s"        : 0,
                "num_chunks"        : 0,
                "processing_time_s" : 0,
                "audio_path"        : str(path),
            })

    df = pd.DataFrame(results)
    Path(output_csv).parent.mkdir(parents=True, exist_ok=True)
    df[["filename", "transcript"]].to_csv(output_csv, index=False, encoding="utf-8-sig")

    total_elapsed = time.time() - total_start
    print(f"\n✅ {len(results)} file(s) processed in {format_time(total_elapsed)}")
    print(f"   Output → {output_csv}")
    return df


print("✅ CT2 inference engine ready.")
# Out:
# ✅ CT2 inference engine ready.

# %% [markdown]
# # RUN INFERENCE

# %%
inference_start = time.time()
print("=" * 65)
print("🚀  CT2 INFERENCE STARTED")
print(f"    {datetime.now(ZoneInfo('Asia/Dhaka')).strftime('%Y-%m-%d %H:%M:%S')}")
print("=" * 65)

df_results = run_ct2_inference(AUDIO_BASE_PATH, OUTPUT_CSV)

total_time = time.time() - inference_start
print("\n" + "=" * 65)
print("🏁  CT2 INFERENCE COMPLETE")
print(f"    Total time : {format_time(total_time)}")
print("=" * 65)
# Out:
# =================================================================
# 🚀  CT2 INFERENCE STARTED
#     2026-03-05 09:29:15
# =================================================================
#    Found 24 audio file(s) to process.
#
# [1/24]
#    test_001.wav  |  56m 11s  |  135 chunks
# [GPU 1] Chunk 2/135: হ্যাঁ...
# [GPU 1] Chunk 4/135: তাই হুম থ্যাঙ্ক ইউ ওয়ার্কাম আপনি জানতেন না যে আপনি এত বেশি সুন্দর দেখতেন আমি ড্...
# [GPU 1] Chunk 6/135: এবং কেন বলছেন মানে আমি একটা ছেলে হই কি আমি একটা মেয়েদের ড্রেস কিনতে পারি না কিং...
# [GPU 1] Chunk 8/135: এক্সকিউজ নি আমি এটা নিচ্ছি কত...
# [GPU 1] Chunk 10/135: আমার...
# [GPU 1] Chunk 12/135: এভাবে রাস্তার মাঝখান দিয়ে গেলে কিন্তু সত্যি...
# [GPU 1] Chunk 14/135: মিস আমি মিস করে ফেললাম কেন যে আমি ইউনিভার্সিটির ফার্স্ট সিয়ারের ওই মেয়েটার প্র...
# [GPU 1] Chunk 16/135: আপনি হয় সামনে যান না হলে পেছনে পেছনে আসুন এভাবে গেলে কিন্তু সত্যি সত্যি এক্সিডে...
# [GPU 0] Chunk 1/135: হ্যাঁ...
# [GPU 0] Chunk 3/135: বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে...
# [GPU 0] Chunk 5/135: জয়েন করছেন খুব জয়েন মানে মানে কি বলছেন আপনি না আপনি এখানকার সেলসম্যান না মানে ...
# [GPU 0] Chunk 7/135: সুন্দর আপনি মাশাল্লাহ যিনি আপনাকে বানিয়েছেন মানে আপনার পরে কিছুক্ষণ কম কিছু এত ...
# [GPU 0] Chunk 9/135: যাক...
# [GPU 0] Chunk 11/135: আমার...
# [GPU 0] Chunk 13/135: গোল্লায় চলে যাবে ওদিকেই তো যেতে যাচ্ছিস কিন্তু কেউ যদি সাথে থাকে একদম কনফার্ম ব...
# [GPU 0] Chunk 15/135: স্মার্ট ভিশন ভালো একটা মেয়ে আমাকে প্রপোজ করে মেয়েটা আপনার সামনে ভাব নেবার জন্য...
# [GPU 0] Chunk 17/135: খুশি খুশি...
# [GPU 0] Chunk 19/135: হ্যাঁ...
# [GPU 0] Chunk 21/135: হ্যাঁ...
# [GPU 0] Chunk 23/135: আপনাকে বউ বানিয়ে এখন পর্যন্ত আমার নামটাই জানলেন না আর আমাকে বউ বানানোর চিন্তা ক...
# [GPU 0] Chunk 25/135: প্রজেক্ট আর আপনিও শুনে রাখুন এই লাভ লোকসানের হিসাব করে জীবন চলে নাকি যেই চেষ্টাট...
# [GPU 0] Chunk 27/135: নামটা বলা যায় আপনাকে আমার নাম পায়েল এত সুন্দর নাম ভ্যার আপনার চাইতে আপনার নাম ...
# [GPU 0] Chunk 29/135: আমি খুব ভালো করে জানি এখন হচ্ছে আপনার ক্যাম্পাস টাইম আপনি এখন ক্যাম্পাসে যাবেন ত...
# [GPU 0] Chunk 31/135: বার্তা একদম আমার সামনে বলবেন না আপনি যখন বলেন না এরকম করে কথা ভীষণ কষ্ট লাগে বরং...
# [GPU 1] Chunk 18/135: ঘুরতে থাকুন লাভ নেই হুম সময় কথা বলবে...
# [GPU 1] Chunk 20/135: আমার...
# [GPU 1] Chunk 22/135: এই এখনো দাঁড়িয়ে আছেন বাসায় যাননি আপনি এখনো বাসায় যাননি ও না না মানে যাব যাব ...
# [GPU 1] Chunk 24/135: শুধু ফারহান নাকি আগে পরে কিছু আছে অনেক কিছু আছে আগে পিছে অনেক কিছু আছে সব বাসায়...
# [GPU 1] Chunk 26/135: হাঁটাহাঁটি করেছি দাঁড়িয়ে ছিলাম খুব ক্ষুধা লেগেছে যদি সম্ভব হয় বাসা থেকে যদি থ...
# [GPU 1] Chunk 28/135: এই যে এই যে এই যে কথা নেই বার্তা নেই হুট করে ভিতরে কোথায় যাচ্ছেন ও আছে ওই যে না...
# [GPU 1] Chunk 30/135: ও সামনে সামনে আরেকটা রিক্সা দাঁড় করি কেন তুই এত বোকা কেন আমি তো ভেবেছিলাম আপনি ...
# [GPU 1] Chunk 32/135: আচ্ছা বাদ দিন তো আপনি আমি আপনি আর আমার পেছনে ঘুরবেন না আমি খুবই বিরক্ত হচ্ছি আপন...
# [GPU 0] Chunk 33/135: কখনো কোনদিন আপনাকে বিরক্ত করবো না আপনার পেছন পেছন ঘুরবো না আপনার সামনে এসেও দাঁড...
# [GPU 0] Chunk 35/135: একদিন ধরেই তো আমার পিছনে ঘুরঘুর করছেন পছন্দ হয় আমাকে ভীষণ প্রেম করবেন আমার সাথে...
# [GPU 0] Chunk 37/135: আমরা কিছুদিনের জন্য টেল রিলেশনে যাব যদি অ্যাডজাসমেন্ট হয় তাহলে কন্টিনিউ করবো ইজ...
# [GPU 0] Chunk 39/135: সেটা তো বুঝতেই পারছি এত জাজমেন্টাল হয়ে চলো না ওকে যাও যাও যাচ্ছি তুমি যাও...
# [GPU 0] Chunk 41/135: আমার...
# [GPU 0] Chunk 43/135: আমার...
# [GPU 0] Chunk 45/135: পারি নাই বলো না কি কি আই থিঙ্ক আই লাইক ইউ টু মানে হইলো না তো বিষয়টা মানে এই যে ...
# [GPU 0] Chunk 47/135: ইয়েস আই ডু ইউ আনলিবাবল বাসায় যাওয়া এখন এই কুয়াশার মধ্যে আরেকটু দাঁড়িয়ে থাক...
# [GPU 1] Chunk 34/135: আমি কই যাই সেটা তোমার জানার দরকার নেই তুমি কই গেছিলা সেটা বলো আজকে তোমার খবর আছে...
# [GPU 1] Chunk 36/135: লাগে ভালো লাগে না কোন কিছু ঘুম আসে না আমার এই যে বুকের এই পাশটাতে ধরফর করতে থাকে...
# [GPU 1] Chunk 38/135: বাসায় যাও ঘুমাও ঘুম ভাঙলে কল দিও অবশ্যই অবশ্যই আজকে বহুদিন পর আমি শান্তিতে ঘুমা...
# [GPU 1] Chunk 40/135: আমার...
# [GPU 1] Chunk 42/135: আচ্ছা দুদিন আগে যে ছেলেটাকে দেখলাম সে ছেলেটার জন্য আমার মনের ভেতরে কোন অস্থির লা...
# [GPU 1] Chunk 44/135: আর কত দাঁড়িয়ে থাকবে বাসায় যাও কি বললে আমি ঠিক বুঝতেছি...
# [GPU 1] Chunk 46/135: লাইক করো না একটা বলতে না না আমি জীবনে কোনদিন তোমাকে এটা বলি নাই বলতাম না আমি এরক...
# [GPU 1] Chunk 48/135: উদ্ধার করে ফেলছি এখন আমি দাঁড়ায় দেখি কি হবে বাসায় যাব বাসায় বসে রাজ্য রাজকন্...
# [GPU 0] Chunk 49/135: এখন আমি মজা নিব না তোকে মজা নিবে তবে একটা বিষয় কিন্তু না বলে আমি পারছি না আমি ক...
# [GPU 0] Chunk 51/135: আচ্ছা বাদ দাও তুমি এখন বাসায় যাও যদি না যাই যদি না যাও তাহলে আমি পুলিশ ডেকে বলব...
# [GPU 0] Chunk 53/135: আমি না রাগে কোন কথাই বলতে পারতেছি না তুমি কোন কথাই বলিও না মানে কিভাবে সম্ভব আগে...
# [GPU 0] Chunk 55/135: সুন্দর তুমি এখানটাতে পড়ায় গেলা গোল্লায় যাও ওখানে তো আছি এখন একসঙ্গে দুজনে চুপ...
# [GPU 0] Chunk 57/135: রাগ করেছো হ্যাঁ রাগ করবো না হাত ধরতে দেইনি বলে আবার জিজ্ঞেস করো...
# [GPU 0] Chunk 59/135: হ্যাঁ...
# [GPU 0] Chunk 61/135: বর্ষা নতুন ছবির ধুম তোমার নীরব কৌতুহল আমি অসীম ছেড়ো তোমার...
# [GPU 0] Chunk 63/135: বর্ষা নতুন ছবির ধুম তোমার নীরব কৌতুহল আমি অসীম ছেলে তোমার আজ আর কথার...
# [GPU 1] Chunk 50/135: অচেনা একজন প্রেমিক পুরুষ তার সাথে দেখা করবার জন্যে একজন এভাবে নিচে চলে আসছে সাহস...
# [GPU 1] Chunk 52/135: সাথে নিয়ে যেতে পারবি গোল্লায় যাও ওখানেই তো থাকি শুধু এরপরের বার তোমাকে সাথে নি...
# [GPU 1] Chunk 54/135: একসঙ্গে এত কথা বললে বুঝবো কি আর বলবো কি মানে এখন না বুঝতে পারলাম যে তুমি রাগ করছ...
# [GPU 1] Chunk 56/135: এত দূরে দাঁড়ায় থাকলে চলবে কাছে আসো না দূর থেকেও ভালোবাসা যায় ভালোবাসা যায় কি...
# [GPU 1] Chunk 58/135: ভাবনা শেষ শেষ কি ভাবনা জীবন সুন্দর তোমার মত সুন্দর...
# [GPU 1] Chunk 60/135: হ্যাঁ...
# [GPU 1] Chunk 62/135: হাজার কথার ছল ভীষণ রোদের ভাটা হবে আমার মনের আকুল ধরাতে গোপন অভিমানে গোপন কথো কথা...
# [GPU 1] Chunk 64/135: আমার...
# [GPU 0] Chunk 65/135: হ্যালো কি ব্যাপার ফোন ধরছো না কেন কয়দিন যাবত তোমাকে ফোন দিচ্ছি কি হয়েছে সত্যি ...
# [GPU 0] Chunk 67/135: বেস্ট নো আমি পরে বল দিই গুড নাইট ওকে থ্যাঙ্ক ইউ ডান বাই লাভ ইউ আরে আয় আয় আয় আ...
# [GPU 0] Chunk 69/135: আর তুই জানিস যে আমার বোন আমার কাছে কত এক্সপেন্সিভ আরে আমার দশ টানা পাঁচ টানা একট...
# [GPU 0] Chunk 71/135: এই দুইটা না একটা দাও এক বেট কেন তুমি খাবে না খাবো না খেতে ইচ্ছে করতো মানে কি আমি...
# [GPU 0] Chunk 73/135: আমার আসলে এভাবে করে রিয়াট করাটা উচিত হয় নাই আমার মুডস উইং হইতেছে খুব বেশি আমিও...
# [GPU 0] Chunk 75/135: কি আমি ফুচকা খাবো না কিসের জন্য কি হইছে হ্যাঁ কি আমি তো ফুচকা আরো খেতে পারলাম না...
# [GPU 0] Chunk 77/135: হ্যালো বলো কি করছো মুড়ি ভাজতেছে তুমি না খালি মজা করো একটা সিরিয়াস টাইপের কথা ব...
# [GPU 0] Chunk 79/135: অবশ্যই আসবো ওকে থ্যাঙ্ক ইউ এখন ঘুমাও গুড নাইট হুম বসো আমি তোমার জন্য...
# [GPU 1] Chunk 66/135: অবস্থায় থাকতে চাই না আমি তোমার জীবন থেকে সরে দাঁড়াবো কি অসুখী ভাবে কথা বললে হব...
# [GPU 1] Chunk 68/135: তুই কি কি দেখিস ভাইয়া এটা তুমি কোথায় নিয়ে আসছো গাধা দেখে বুঝতে পারছিস না এটা ...
# [GPU 1] Chunk 70/135: তার মনটাকে সবচাইতে সুন্দর লাগবে এবং বোনটা তার পছন্দের সবচাইতে সুন্দর কাপড়টা এখা...
# [GPU 1] Chunk 72/135: দেখো আমার সিক্সেন্স খুবই ভালো আমার সামনে কেউ মিথ্যা কথা বলতে পারে না কিন্তু ধরে ...
# [GPU 1] Chunk 74/135: খাওয়াটা তাড়াতাড়ি শেষ করো তুমি তোমার বাসায় যাও বাড়িতে যাও মানে তুমি আমাকে দি...
# [GPU 1] Chunk 76/135: আমার...
# [GPU 1] Chunk 78/135: আমি চিন্তা করছিলাম তোমার পছন্দের একটা রেসিপি রান্না করবো তোমার কালকে দাওয়াত আমা...
# [GPU 1] Chunk 80/135: পায়েশ রান্না করেছি নিয়ে আসছি মাসে কেউ নেই না না কেউ নেই আচ্ছা কেউ নেই আরে শোনো...
# [GPU 0] Chunk 81/135: ভালোবাসেন করো না প্লিজ বসো কি হইছে তোমার তুমি এরকম কেন করতেছো দেখো একটা মানুষের ...
# [GPU 0] Chunk 83/135: তোমার কি ধারণা যে আমি ফান করছি তোমার সঙ্গে আমারে মনে হচ্ছে আমি ফান করছি না আমি স...
# [GPU 0] Chunk 85/135: বেবি বেবি বেবি বেবি চুপ করেছি না কোন চিৎকার হবে না সাইকো ওই গেছিল আমি মাই সাইকো ...
# [GPU 0] Chunk 87/135: হ্যাঁ বলো ভাইয়া কতবার করে আমি তোকে ফোন দিচ্ছি তুই ফোন ধরতেছিস না না পারতে ভিডিও...
# [GPU 0] Chunk 89/135: ভাইয়া আমাকে রাখি কারা যেন ফলো করছে কারা দুইজন লোক আমাকে ফলো করছে আছিস না কোন দি...
# [GPU 0] Chunk 91/135: আমার...
# [GPU 0] Chunk 93/135: তোমারেও নিয়ে যাও আজকের রাতেও তোমার সাথে থাকা মা কিচ্ছু হবে না সব ঠিকই ভাই আছে ন...
# [GPU 0] Chunk 95/135: আমার...
# [GPU 1] Chunk 82/135: ছোট্ট এত সুন্দর করতে তোর মন লাগে বাঁধা পড়লে সেটা দেখছে এই গুলো করা গেল খোলো কি ...
# [GPU 1] Chunk 84/135: না না না না না না না না না না না না...
# [GPU 1] Chunk 86/135: আজকে তোর এই দশা শুধুমাত্র আমার বোনের সঙ্গে যা ঘটেছিল সেই জন্য তোমারে কি করতে পার...
# [GPU 1] Chunk 88/135: কথা হলো নাকি তোর আক্কেল জ্ঞান কবে হবে সেন্ট ফ্রাই কত রাত হয়েছে আর তুই আস ঠিক আছ...
# [GPU 1] Chunk 90/135: না শুনতে পারতে ভাইয়া ভাইয়া...
# [GPU 1] Chunk 92/135: মা আজকে রাতটা ওকে একা থাকতে দিবে...
# [GPU 1] Chunk 94/135: হ্যাপি...
# [GPU 1] Chunk 96/135: মা হুয়াত মা হুয়াত মা...
# [GPU 0] Chunk 97/135: তোমায় হোম মেয়েটা...
# [GPU 0] Chunk 99/135: মা ভালো...
# [GPU 0] Chunk 101/135: না না...
# [GPU 0] Chunk 103/135: আমার বোনটার সঙ্গে যা যা ঘটছে তোর ভাই তার বোন এই যে তুই তোর ভাইয়ের বন্ধু তার বোন...
# [GPU 0] Chunk 105/135: কেউ এভাবে চিৎকার করছিল আমার বউ বাঁচার জন্য আপত্তি করছিল কেউ বাঁচায় নাই আমি ছিলা...
# [GPU 0] Chunk 107/135: না কোনভাবে উচিত না কিন্তু অমানুষ বোঝে না বলতে বাধ্য হইতেছি তোর ভাই তোর ভাইয়ের ব...
# [GPU 0] Chunk 109/135: বিচার হবে বিচার হবে বিচার...
# [GPU 0] Chunk 111/135: কোথায় ছিলি সারাদিন সেই সকালবেলা বের হয়ে যাস আর আসার কোন খবর থাকে না আমি একা এক...
# [GPU 1] Chunk 98/135: নাও...
# [GPU 1] Chunk 100/135: মাথা না মাথা না বাবা চাপে আছে...
# [GPU 1] Chunk 102/135: আমি বিশ্বাস করি না আমার ভাই করছে শুধু তোর ভাই একারো তোর ভাইয়ের বন্ধু দুজন দুজন ...
# [GPU 1] Chunk 104/135: ওই পরিবারের মায়ের ভাই তারাকে দেখবি না পারুন পারুন পারুন আমার কি দোষ পারুন আমি ত...
# [GPU 1] Chunk 106/135: চুপ তুই বলতেছিস এই যে ঘটনাটা ঘটে এটা শুধুমাত্র ওই একটা মেয়ের সঙ্গে ঘটে তার পরিব...
# [GPU 1] Chunk 108/135: কেমন ভয় ঘটনাটা আর ওই পরিবার আমি নিশ্চয়ই সেদিকে তুঙ্গ করে দেয় জীবিত অবস্থায় ম...
# [GPU 1] Chunk 110/135: না বাবা...
# [GPU 1] Chunk 112/135: তুই কাজ ছিল মা কাজ শেষ করতে করতে দেরি হয়ে গেল কাজ শুধুই অপেক্ষা...
# [GPU 0] Chunk 113/135: তোর অপেক্ষা সময়ের অপেক্ষা উপরে যাওয়ার অপেক্ষা আমার ভালো লাগে না আমার দম বন্ধ হ...
# [GPU 0] Chunk 115/135: সে তো নাই কি অপরাধ ছিল ওর আমার মেয়েটা কি অপরাধ ছিল ওকে তো আমি পারিবারিক শিক্ষায...
# [GPU 0] Chunk 117/135: কি অপরাধ ছিল আমার কি অপরাধ ছিল তোর কি অপরাধ ছিল আমাদের আমার পরিবারের একটা মায়ের...
# [GPU 0] Chunk 119/135: কোন অপর না করে শাস্তি পেল শাস্তি দিল নিজেকে আমার বোনটা আমার বোনটাও তো একটা মানুষ...
# [GPU 0] Chunk 121/135: বিচার আমরা করব বিচার হবেই বিচার করবো মা বিনা অপরাধে কেউ শাস্তি পাবে না মা বিনা অ...
# [GPU 0] Chunk 123/135: মা কি হইছে তোমার খাইতাছো না কেন আমার কিচ্ছু হয়নি ক্ষুধা নেই আমার খেতে ইচ্ছে করছ...
# [GPU 0] Chunk 125/135: আমরা ভুল ঠিকানায় আসছি না এই ওনাকে নিয়ে আসো...
# [GPU 0] Chunk 127/135: সুমন আমার সন্তান ওকে আমি দশ মাস দশ দিন পেটে ধারণ করেছিলাম একটা রেপিস্ট কারো সন্ত...
# [GPU 0] Chunk 129/135: তার এই অদ্ভুত জীবনে মানুষ নানা রকমের অনাকাঙ্ক্ষিত ঘটনার এত সম্পৃক্ততা দূর আর এই ...
# [GPU 0] Chunk 131/135: তবে একটা কথা জানো কি আমার জীবন বইয়ের এই অধ্যায়ে আমি তোমাকে প্রচন্ড ভালোবাসি...
# [GPU 0] Chunk 133/135: আমার...
# [GPU 0] Chunk 135/135: আমার...
# [GPU 1] Chunk 114/135: এই আমি তোমাকে ছেড়ে কোথাও যাব না আমি ছিলাম আমি আছি আমি থাকবো মা আমার মেয়েটারও ত...
# [GPU 1] Chunk 116/135: তোর বোনটা আজকে কেন নাই কেন তার সাথে এমন হলো কেন আমার মেয়ের লাইফে এরকম একটা এক্স...
# [GPU 1] Chunk 118/135: আমার শুধু ভয় হয় আমি যদি তোকে হারিয়ে ফেলি আমাকে ফেলে যাস নি যদি কিছু হয় আমি ক...
# [GPU 1] Chunk 120/135: এই যে আমাদের সমাজ এই যে আমাদের পরিবার এই যে আমাদের দেশ এই দেশের যে মেয়েরা এই যে...
# [GPU 1] Chunk 122/135: হবেই...
# [GPU 1] Chunk 124/135: কি আপনি আছেন আপনাকে চিনলাম না আমি ওস আই মিলন উত্তরা থানা থেকে আছি আপনার নামে ওয়...
# [GPU 1] Chunk 126/135: মা মা এখানে বসো এখানে বসো তোমার চোখ দিয়া এক ফোঁটা পানি পড়বে না এক মিস্টার আর র...
# [GPU 1] Chunk 128/135: একটা বিষয় উপলব্ধি করবে কি মানুষের জীবনটা বড়ই অদ্ভুত...
# [GPU 1] Chunk 130/135: কিন্তু এই অনাকাঙ্ক্ষিত ঘটনাগুলো যত তাড়াতাড়ি ভুলে যাওয়া যায় জীবন তো সহজ হয় এ...
# [GPU 1] Chunk 132/135: আমার...
# [GPU 1] Chunk 134/135: আমার...
#    ✓ Done in 1m 5s  |  speed 51.08× realtime  |  19460 chars
#
# [2/24]
#    test_002.wav  |  40m 36s  |  98 chunks
# [GPU 0] Chunk 1/98: আমার...
# [GPU 0] Chunk 3/98: দূরে যাও তুই যে তোমার তোমাদের পরিচয় বলো ভাই আমি রাতুল ওই যে ফোনে কথা বললাম ও ওই...
# [GPU 0] Chunk 5/98: কখনো পিক করতে আসবেন না আমার গার্লফ্রেন্ডের পিছনে টাকা খরচ করতে করতে আমার সব শেষ ...
# [GPU 0] Chunk 7/98: রাজি জান জায়গাটা সুন্দর না ভাই দুটা গোল্ড কফি দিয়েন হ্যাঁ তোমার মতোই ক্ষেত জায...
# [GPU 0] Chunk 9/98: হ্যাঁ তুমি আমাকে চিনতে পারতেছো না জান আপনাকে আমি জীবনে প্রথম দেখলাম এই তুমি ফালত...
# [GPU 0] Chunk 11/98: এমন করো না আমি তো মারবো জানে আমি বলতেছি আমি একটা তো পূর্ব মারতেও পারবো নাকি আমি ...
# [GPU 0] Chunk 13/98: কেন এই যে বড় লোকের নাকি বাইরাও বাইরাও বাইরাও বাইরাও বাইরাও ছোট লোক আরে মিয়া হা...
# [GPU 0] Chunk 15/98: বছরের সম্পর্ক ছেড়ে চলে যাচ্ছে এই বকবক না করে বাইর হতে বাইর হও আবলতে আবলতে বলতেছ...
# [GPU 1] Chunk 2/98: এই আমি আমি কিন্তু ইচ্ছাধারী নাগিন স্যার নাগ আমি কিন্তু ছমল দিলে তোমরা একদম বাচ্চ...
# [GPU 1] Chunk 4/98: কচি গুন্ডা গুনে সম্পন্ন এদেরকে দেখলে তো যে কেউ দূর দিবে এত মানুষ নিয়ে আসে সমস্য...
# [GPU 1] Chunk 6/98: আমার থেকে না দুনিয়া থেইকা সইরা যাক আমি তো মার্ডার কই না ভাই না না ওইটা না ভাই আ...
# [GPU 1] Chunk 8/98: তোমার এই রেডিসন আর রুফট টপে চিল করতে করতে আমার কাউকে পইড়া যাইতাছে যান তুমি না হ...
# [GPU 1] Chunk 10/98: আপনি ওকে চেনেন না এই তোমারে কি যাতে আমারই মারবো আমি তোমারে তুমি আমারে চিপ করতেছো...
# [GPU 1] Chunk 12/98: আমি যদি মরে যাই না ওদাই পুলিশকে বলে হ্যাঁ এখন কে হ্যাঁ কি শুরু করছে তোর লগে ব্রে...
# [GPU 1] Chunk 14/98: এই অ্যাঙ্গেজমেন্ট হতে পারে না ও আমার প্রেমিকা তুমি কেন এমন করতেছো সোনা এইভাবেই ত...
# [GPU 1] Chunk 16/98: ও আমাকে চেনে না চেক করে দেখেন ওর পিঠের মাঝখানে একটা তিল আছে দেখো তো দেখি আরে দেখ...
# [GPU 0] Chunk 17/98: দূর আপু আমি এই মেয়েকে বিয়ে করবো না এই মেয়ের সব তো ওই ছেলে দেখেই ফেলছে আমি কি ...
# [GPU 0] Chunk 19/98: পাগল তোমার মনে আছে এইসব জায়গায় আমরা কত কত এসেছি কত ঘুরেছি একটা সময় তো ঘুরতে ঘ...
# [GPU 0] Chunk 21/98: মানুষ ভুলেও যায় ভুলে যায় সত্যিই ভুলে যায় আচ্ছা শোনো না কি খাবা তুমি প্রকৃতি আ...
# [GPU 0] Chunk 23/98: শান্ত শান্ত খাবারটা নিয়ে এসো ওয়ালাইকুম আসসালামু আলাইকুম আসসালাম ওয়ালাইকুম আসস...
# [GPU 0] Chunk 25/98: এই এই আল্লাহ দেখি তাকাও তাকাও দেখি কান্না করতেছো কেন হ্যাঁ দেখো আমার ছেলেটা আমার...
# [GPU 0] Chunk 27/98: কি বলার ছেলে ছেলে সময় ছেলে সময় মানে আমি চলে যাই তাহলে না না না না না শোনো দেখো...
# [GPU 0] Chunk 29/98: ভাই এই যে ভাই আপনার ডিস্টার্ব করছে আরে বাবু তুমি বলো নাই...
# [GPU 0] Chunk 31/98: কি হলো খেয়াই জানবো না তোমাকে জোসবো আচ্ছা বাই বাই মানে এই কি আমি মাত্র আপনার উপক...
# [GPU 1] Chunk 18/98: এটা সো মাচ আপনি যদি না থাকতেন আজকে আমার চেয়ে কি হতো মিষ্টির জন্য না না না এখন এ...
# [GPU 1] Chunk 20/98: আসলে ভুলে গেছো হ্যাঁ মানে ঘুমায় ঘুমায় মনে হয় ভুলে গেছো হয় কি মানে যে তুমি রক...
# [GPU 1] Chunk 22/98: উফো তুমি কি ভুলে গেছো ফ্রাইট কিছু খেলেই তো তোমার ঝামেলা হয় ফ্রাইট খেলা আমার ঝাম...
# [GPU 1] Chunk 24/98: উনি আঙ্গুলে কি তোমার হাতে বুঝছো এই আল্লাহ এ কি অবস্থা আরে বোকা নাকি এই এমনটা কেউ...
# [GPU 1] Chunk 26/98: শুনেছি আমাকে বলল আমাকে বলল আমি দেশের বাইরে চলে যাব যেখানে যেতে চাইছি আমি সেখানেই...
# [GPU 1] Chunk 28/98: আমার আরো কিছু মা আছে ওদেরও সময় দিতে হয় আবার অনেকগুলো মানুষ আছে যাদের তোমার ছেল...
# [GPU 1] Chunk 30/98: আরে ভাই কি অবস্থা ভালো আছেন কে আপনি আমার কথা বলেন না আপনার বোন আপনাকে আল্লাহ আমা...
# [GPU 1] Chunk 32/98: কি ভাড়া ভাড়া কিসের ভাড়া আচ্ছা আমি আপনি ব্যাপারটা বুঝে বলি না আপনি যদি একজন মা...
# [GPU 0] Chunk 33/98: জীবন হতাশায় ভরে গেছে প্রেমে বিচ্ছেদ হারানো প্রেমিককে ফিরে পেতে চান বা ফিরে আসা ...
# [GPU 0] Chunk 35/98: নাম্বার আপনার লাগবে চিনতে পারছেন আমাকে আপনি কি কালকে আমার সাথে একটু দেখা করতে পা...
# [GPU 0] Chunk 37/98: সুন্দর শোনেন এই বাসার ছাদটা আমার না ইভেন এই বাসাটাও আমার কি বলেন তবে এটা কার বাস...
# [GPU 0] Chunk 39/98: ভাই আপনার বলা শেষ হইছে জি এখন আপনি আমার কথাটা শুনবেন প্লিজ জি আমি একটা বড় বিপদে...
# [GPU 0] Chunk 41/98: না বলেন বলেন বলেন আমি ওকে ফোন দিতে দিতে ও যখন কোনভাবে আর ফোন ধরতেছে না আমি অনেক ...
# [GPU 0] Chunk 43/98: আমার বয়ফ্রেন্ড ওর ফ্রেন্ডের বেডরুমে অন্য একটা মেয়ের সাথে জাস্ট এইভাবে হাত ধরে ...
# [GPU 0] Chunk 45/98: আপনি আমাকে বিয়ে করবেন তারপর আমার বাসায় যাবেন আমি রাজি কিন্তু একটু মানে...
# [GPU 0] Chunk 47/98: আমার মা খুব অসুস্থ হ্যাঁ আমার বাসায় একটা ছোট বোন আছে হ্যাঁ আমি যেহেতু বিয়ের কথ...
# [GPU 1] Chunk 34/98: কত নরমালি তো আসলে আমি পাঁচ হাজার টাকা চার্জ করি একদিনের জন্য কিন্তু যেহেতু আপনি ...
# [GPU 1] Chunk 36/98: আপনাকে কি কবুতর খাওয়ানোর জন্য এখানে ডাক হয়েছে ও সরি আপনি আগে বসেন আগে কথা বলেন...
# [GPU 1] Chunk 38/98: না হলে দেখা যাবে কোথায় না কোথায় খুন করে রেখে আসছেন পুলিশ তো এসে আমাকে ধরবে এই ...
# [GPU 1] Chunk 40/98: আপনি কথা কেন শুনেন না আপনি এত কথা বলেন কেন আমি আমার বাসা থেকে পালায় বের হইছি কা...
# [GPU 1] Chunk 42/98: ফাজিল কোথাকার নষ্ট দুশ্চরিত্র মহিলা আপনি আপনি এখানে আসছেন কেন আপনি তো মানে আপনি ...
# [GPU 1] Chunk 44/98: সরি আই থোর যে আপনার একটা হাক থেরাপি দরকারের জন্য মানে আমি আপনাকে দেখান এই যে কান...
# [GPU 1] Chunk 46/98: পরিবার কি আপনার ছবিটা একটু পাঠাতে হবে আমি শোনেন আপনি আমাকে সত্যি সত্যি বিয়ে করত...
# [GPU 1] Chunk 48/98: নিতে হয় সেই ক্ষেত্রে আপনাকে ওভারটাইম পে করতে হবে ডান নাম্বার টু নয়শত উনসত্তর ট...
# [GPU 0] Chunk 49/98: দাঁড়াও লাগবে না আসসালামু আলাইকুম আসসালাম কি নাম তোমার...
# [GPU 0] Chunk 51/98: তুমি বিজনেস বিজনেস করো কিসের বিজনেস ভাড়া চালিত কিসে চালিত আমি বলছি বাবা ট্রান্স...
# [GPU 0] Chunk 53/98: তোমরা কানে কানে কি কথা বলো না বাবা কিছু বলছি না আমি বলি ও লজ্জা বলতে চাচ্ছে না আ...
# [GPU 0] Chunk 55/98: আর যা হবার হয়েছে আমি আগামী সাত দিনের মধ্যে অনুষ্ঠানের ব্যবস্থা করবো ঠিক আছে শোন...
# [GPU 0] Chunk 57/98: এটা কি গ্লাসের মধ্যে কেউ কাটা ফেলে কিছু নাই তো ফালানোর মতো কিসে ফালাবো এরকম কোন ...
# [GPU 0] Chunk 59/98: আগেই মনে হইছিল আপনি রাত হইলে আমার সাথে উল্টাপাল্টা করার চেষ্টা করবেন ওদিকে যান ম...
# [GPU 0] Chunk 61/98: আপনি ওইদিকে যান আমি এখানে ঘুমাবো আমি তো আপনার সাথে কোনভাবে বেড শেয়ার করবো না আপ...
# [GPU 0] Chunk 63/98: হ্যালো কি বলতেছে এসব হাসিব একটাবার বোঝার চেষ্টা করো...
# [GPU 1] Chunk 50/98: বাড়ি কোথায় আমি ধানমন্ডিতে থাকি গ্রামের কোন বাড়ি নাই অর্ফারেন্সি বড় হয়েছি তো...
# [GPU 1] Chunk 52/98: হ্যাঁ বাবা মানে তোমার বড় মেয়ের জামাই একজন ড্রাইভার না না বাবা ড্রাইভার না মানে...
# [GPU 1] Chunk 54/98: বেশি করে খাও থ্যাঙ্ক ইউ থ্যাঙ্ক ইউ রোসটা আমার অনেক পছন্দ শোনো ওই অন্যের গাড়ি চা...
# [GPU 1] Chunk 56/98: পছন্দ করে এটা আমি আছি ওকে দেন একটা দেন...
# [GPU 1] Chunk 58/98: আমি এটা নিতে গেছিলাম এত ভাত খাইতে পারবো না তখনই খেলাম প্রেমের সমান নিচে গেছে পাখ...
# [GPU 1] Chunk 60/98: রাখতে গেছেন আমি আমার বাসায় কম ফ্লোটেড ছিলাম না কেন আপনি অন্য কোথাও ঘুমান এখানে ...
# [GPU 1] Chunk 62/98: দিয়ে তাই না এটা তো রাতের ঘটনা ডে পেমেন্ট হিসেব করেন কেন চুপ বিয়ে বসেছেন না আমা...
# [GPU 1] Chunk 64/98: আমি তোমার কি ক্ষতি করেছি আমি তো তোমার কোন ক্ষতি করি নাই কিন্তু কেন তুমি আমার সাথ...
# [GPU 0] Chunk 65/98: হাজিম আমার গলায় দড়ি দিয়া ছাড়া কোন উপায় থাকবে না হাজিম আমি আমি দশ লাখ কোথায়...
# [GPU 0] Chunk 67/98: হাসিব একটা করে বোঝার চেষ্টা করো কি বুঝো তোমারে আমি কি এত কথা শুনতে চাই না ভাই তো...
# [GPU 0] Chunk 69/98: কেমন আছো তুমি এইতো হ্যাঁ তুমি কি করতেছো না লংটন প্র্যাকটিস করতেছো না তুই এটা কি ...
# [GPU 0] Chunk 71/98: এখানে পুতে থুইয়ে দিব ভাইয়া তুমি তো আমাকে চেনো তাই না ফোনটা ছাড়ো হ্যাঁ জোর করত...
# [GPU 0] Chunk 73/98: ফোনে কথা হলো বিজনেসের জন্য আমি তাকে কিছু টাকা আছে কিছু টাকা নিয়েছিলাম এখন সে থ্...
# [GPU 0] Chunk 75/98: ডিস্টার্ব করে যাই হোক আমি কিন্তু এগুলোরে অনেক সেটিং মেটিং দিয়ে তারপর মনে করেন এ...
# [GPU 0] Chunk 77/98: সরি মানে শ্বশুর আব্বা আমারে বন্ধুবান্ধবের না আপনি আমারে জামাই মেনে নিলেন ছেলে মে...
# [GPU 0] Chunk 79/98: বাবা তোমাকে সহ্য করতে পারতো না তোমাদের দুইজনের ফ্রেন্ডশিপ আর মা যে তোমার উপর সবস...
# [GPU 1] Chunk 66/98: তাহলে তুমি আমাকে বলো হাসিবকে ভাইয়া হাসিবের সাথে আমার রিলেশন ছিল ও এখন বলছে ওর আ...
# [GPU 1] Chunk 68/98: শুনতাম দশ লাখ টাকা মানুষ ব্যাগে কইরা দেয় বিটপ্লিসে কইরা দেয় তুমি খামি দিতাছো আ...
# [GPU 1] Chunk 70/98: শুনলাম তুমি নাকি ভাইয়া ওই যে কাকে যেন ফলো করো না না ভাইয়া সিরেন্স জনি না না ভা...
# [GPU 1] Chunk 72/98: কি ব্যাপার সুর আব্বা আপনি সিগারেট খাওয়াতে বলেন আবার কবে হ্যাঁ বলো না এক লোকের স...
# [GPU 1] Chunk 74/98: যদি থ্রেড খেতে হয় মানুষ উল্টাপাল্টা কথা বলে তখন সিগারেট খাবার তো কি করবো তাহলে ...
# [GPU 1] Chunk 76/98: আরে ধুর সরি আব্বা আপনি এটা একটা কথা বললেন এটা কোন ম্যাটারই না এটা আমার বাম হাতের...
# [GPU 1] Chunk 78/98: কিন্তু আমার তো মনে হইছে ম্যাজিক হলো ম্যাজিক ধরো আমার ছোট বোন প্রথমে তোমাকে দেখে ...
# [GPU 1] Chunk 80/98: আর আমি...
# [GPU 0] Chunk 81/98: ওইটা ওইটা বাপ তুমি তো যে কয়টা পড়ছো ওইকটাই ভালো লাগছে আমার কাছে এই তোকে এত বার ...
# [GPU 0] Chunk 83/98: সম্বন্ধে লেটিং ক্লিয়ার ওর সাথে আমার পারো আমার আমি তোমাকে বিশ্বাস করেছিলাম ফ্যাম...
# [GPU 0] Chunk 85/98: মূল্যটা তুমি নষ্ট করে দিলে আব্বা সরি আঙ্কেল আসলে ধরেন একটা মানুষ যদি সাত আট দিন ...
# [GPU 0] Chunk 87/98: না হঠাৎ করে যখন মিথ্যা মিথ্যা করতে করতে আপনাদের মাইনষে চলে আসছি আমি না মানে একটু...
# [GPU 0] Chunk 89/98: প্রিয়ন্তি তুমি এখনো আমার উপর ভুল বুঝে আছো তুমি সেদিন যেগুলো দেখেছিলে সম্পূর্ণ ভ...
# [GPU 0] Chunk 91/98: সম্পর্কে কি হয় ভাই আমার কাজিন কোনটা লাল ডানা কালাটা ওই...
# [GPU 0] Chunk 93/98: আমার বোন কাজিনের জীবন এরকম মতেই তো অনেকেরই থাকে তাতে কিচ্ছু হয় না হয় শুধু অতীত...
# [GPU 0] Chunk 95/98: আটকা রাখতে পারেন না বিয়েবাড়িতে কি করে একদম চুপ আপনি আমার হাজবেন্ডকে পাগল বলতেছ...
# [GPU 0] Chunk 97/98: আমাদের...
# [GPU 1] Chunk 82/98: আপনার দুজন না গিয়ে আজকে যেই মিসটা করছেন এত সুন্দর একটা স্যুট দেখছি আমি আপনার জন...
# [GPU 1] Chunk 84/98: তোমাকে এত বিশ্বাস করলাম বিশ্বাসের মূল্যটা দিলে না আমার সাথে মিথ্যা কথা বললে তোমা...
# [GPU 1] Chunk 86/98: ও কিন্তু খাওয়া শুরু করবে আমি তো ওই অর্ফানে যে বড় হইছি না আমার কাছ থেকে কখনো বা...
# [GPU 1] Chunk 88/98: থাকতে পারবো না শেষ দেখাটা এরকম না হোক আমাকে মাফ করা যায় না...
# [GPU 1] Chunk 90/98: গড সোয়ার ওর সাথে আমার কোন কানেকশন নেই আমি বাবামাকে আমাদের ব্যাপারটা কনভিন্স করে...
# [GPU 1] Chunk 92/98: কালাডা মানে আমার ওই পোলাটা ও পোলা না এই যে ভদ্রলোকের মত চেহারার যে লোকটা কাচুমাচ...
# [GPU 1] Chunk 94/98: চলো এক্ষুনি চল আরে না আমি উনাকে আমি চিনি না আসলে কি কয়েকদিন আগে আমার হাজবেন্ড ন...
# [GPU 1] Chunk 96/98: হাই লাভ ইউ আরে একটা ছোট ধর এটা রে ধর...
# [GPU 1] Chunk 98/98: যা...
#    ✓ Done in 50s  |  speed 48.38× realtime  |  22367 chars
#
# [3/24]
#    test_003.wav  |  1h 5m 2s  |  157 chunks
# [GPU 0] Chunk 1/157: গল্পটির সত্য আনন্দ পাবলিশারস প্রাইভেট লিমিটেড কর্তৃক সংরক্ষিত তোর নাম কানাই তো ত...
# [GPU 0] Chunk 3/157: সানডে সাসপেন্স সত্যজিৎ রায়ের জন্ম মাসে সানডে সাসপেন্সের বিশেষ উদ্যোগ মে মাস রে ...
# [GPU 0] Chunk 5/157: প্যাস্টারাল এন্টারটেইনমেন্ট নসু কোবরেজ প্রায় পাঁচ মিনিট ধরে বলরামের নাড়ি ধরে ব...
# [GPU 0] Chunk 7/157: কাছে গিয়ে তারা হাতে পায়ে ধরে তাকে নিয়ে এসেছে তার বাপের চিকিৎসার জন্য এ রোগের ...
# [GPU 0] Chunk 9/157: বছর পাঁচেক আগে আর এখন বাপের এই বিদ ঘটে ব্যারাম দেখি চাঁদনি নারী ছেড়ে মাথা নেড়ে...
# [GPU 0] Chunk 11/157: চাঁদনি একটা গাছের নাম বুঝি ঢোক গিলে জিজ্ঞেস করল কানাই নসু কবরেজ ওপর নিজে মাথা না...
# [GPU 0] Chunk 13/157: মাতানো গন্ধ বিষাদ দূর থেকে সে গন্ধ পাওয়া যায় স্বর্গের পারিজাতকে হার মানায় সে ...
# [GPU 0] Chunk 15/157: আর দিনে দিনে শরীর শুকিয়ে যেতে থাকে তবে চাঁদনির রস এর অব্যর্থ ওষুধ তো ঠিক আছে ব্...
# [GPU 1] Chunk 2/157: কোন জাদুঘর নাকি আজই শেষ দিন আমার বাবাকে বাঁচাবার শেষ সুযোগ এ রাজা পিশাচ বলবন তার...
# [GPU 1] Chunk 4/157: মৃত্যু এক হাজার নয়শত বিরানব্বই সাল সালের তেইশশ এপ্রিল বাংলা সাহিত্য চলচ্চিত্রের...
# [GPU 1] Chunk 6/157: আজ দশ দিন হলো তার বাপের অসুখ কোন কিছু খাবারে তার রুচি নেই একটানা দশ দিন না খেয়ে...
# [GPU 1] Chunk 8/157: আকাশ ভেঙে পড়বে আপন লোক বলতে তার আর কেউ নেই নন্দী গ্রামে দু বিঘা জমি আর একজোড়া ...
# [GPU 1] Chunk 10/157: জবাব দিয়ে গেলে রোগীকে বাঁচানো শিবের অসাধ্য আর তিনি ওষুধ বাতলে গেলে রোগী চাঙ্গা ...
# [GPU 1] Chunk 12/157: পঁচিশ পা গেলেই দেখবে চাঁদনী গাছ কিন্তু সে তো প্রায় পাঁচ ক্রস পথ পারবে যেতে নিশ্...
# [GPU 1] Chunk 14/157: ময় আছে আর মাত্র দশ দিন দশ দিনের মধ্যে না খাওয়ালে আমি কাল সকাল সকাল বেরিয়ে পড়...
# [GPU 1] Chunk 16/157: রাখার কথা বলে পরদিন ভোর থাকতে গুড় চিড়ে গামছায় বেঁধে নিয়ে কানাই বেরিয়ে পড়লো...
# [GPU 0] Chunk 17/157: মানুষটার হঠাৎ যে কি হলো দেখতে দেখতে শুকিয়ে আধখানা হয়ে গেল হ্যা গো বাদরার বোন ক...
# [GPU 0] Chunk 19/157: তাকে জিজ্ঞেস করে কানাই জানলো ওটাই বাদরাক বল কানাই পা চালিয়ে এগিয়ে চলল শাল সেগু...
# [GPU 0] Chunk 21/157: তারপর চাঁদনি গাছ খুঁজে বার করা মন্দির দেখতে পাওয়ার আগে কিন্তু গন্ধটা পেল কানাই ...
# [GPU 0] Chunk 23/157: ফুল পাতার ছাউনির সামনে তিন হাত লম্বা সাদা দাড়িওয়ালা একটা লোক ভোর গুচকে চেয়ে আ...
# [GPU 0] Chunk 25/157: ওরে বাবা একশত ছাপ্পান্ন বছর বয়সে স্মরণশক্তি কি আর সেই জোয়ান বয়সের মত কাজ করে ...
# [GPU 0] Chunk 27/157: তো আর নেই হ্যাঁ হ্যাঁ রে গিয়ে দেখ শেকর অব্দি সে গাছ তুলে নিয়ে গেছে কানাইয়ের ব...
# [GPU 0] Chunk 29/157: নিয়ে এসে সে গাছ সে গাছ তুলে নিয়ে গেছে রূপসার প্রজাদের ব্যারামও হয়েছে হ্যা সুখ...
# [GPU 0] Chunk 31/157: তোর বাপ ভালো হয়ে উঠবে তাই দেখছেন সত্যি তাই দেখছেন কিন্তু ওষুধ না পেলে কি করে ভা...
# [GPU 1] Chunk 18/157: কিন্তু তাহলে কি হবে বাপের জন্য চাঁদনি পাতা জোগাড় করতে সে প্রাণ দিতে প্রস্তুত সূ...
# [GPU 1] Chunk 20/157: আছে সেটাই একটা সুবিধে বিশ পঁচিশ হাত ভেতরে ঢুকতেই একটা হরিণের পাল দেখতে পেল কানাই...
# [GPU 1] Chunk 22/157: চারপাশটায় গাছ একটু পাতলা বলে পরন্ত রোদ এখানে ওখানে ছিটিয়ে পড়েছে এই এই এই কে র...
# [GPU 1] Chunk 24/157: সে কি মানুষের মনের কথা বুঝতে পারে নাকি কি খুঁজছি তা তুমি জানো দাঁড়া দাঁড়া দাঁড...
# [GPU 1] Chunk 26/157: হ্যাঁ চাঁদনী তাই না হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ তোর বাপের অসুখ তার জন্য চাঁদনি পাতা ...
# [GPU 1] Chunk 28/157: ওই যে গর্ত ওইখানেই ছিল গাছ শিকুর অব্দি তুলে নিয়ে গেছে কিন্তু কে কানাইয়ের চোখে ...
# [GPU 1] Chunk 30/157: ওই চাঁদনি পাতার রস কানাইয়ের আর কথা বলতে ইচ্ছে করছিল না সে চোখে অন্ধকার দেখছিল ক...
# [GPU 1] Chunk 32/157: ওই রূপসার রাজ্যে সে কতদূর এখান থেকে দাঁড়া দাঁড়া একটু একটু একটু ভেবে দেখি বুড়ো...
# [GPU 0] Chunk 33/157: ও রূপসা মানে যেখানে ত্রাতের কাপড়ের খুব নামড়াক ঠিক বলেছিস রূপসার শাড়ি ধুতি চাদ...
# [GPU 0] Chunk 35/157: কিন্তু কোবরেজ বলেছে দশ দিনের মধ্যে বাপকে ওষুধ খাওয়াতে না পারলে বাপ আর বাঁচবে না...
# [GPU 0] Chunk 37/157: এটা খেলে তুই হরিণের চেয়ে তিন গুণ জোরে দৌড়াতে পারবি এক্রোশ পথ তোর যেতে লাগবে মা...
# [GPU 0] Chunk 39/157: তবে কিছু যে একটা হয় সেটা আমি জানি আর যেটা হবে সেটা তোর উপকারেই লাগবে যদি আমার ক...
# [GPU 0] Chunk 41/157: তোর নাম ধরে ডাকবো হুম আরে তোর নাম কানাই তো হ্যাঁ সেই ডাক তুই এই ঝিনুকের মধ্যে শু...
# [GPU 0] Chunk 43/157: আজ তো সন্ধে হয়ে গেল তুই এখন রূপ সাগিয়ে কিচ্ছু করতে পারবি না আমি বলি কি আজ রাতট...
# [GPU 0] Chunk 45/157: মনে পড়েছে আমায় লোকে জগাই বাবা বলে ডাকে তুইও তাই ডাকিস পরদিন সকালে লাল ফলটা খেয...
# [GPU 0] Chunk 47/157: দেখতে দেখতে দুদিকের দৃশ্য বদলে যাচ্ছে গ্রাম থেকে শহর শহর থেকে মাঠ মাঠ থেকে বোন ব...
# [GPU 1] Chunk 34/157: আমি ত্রিকালজ্ঞ আমার নাম একটা আছে তবে তবে এখন আমার সেই নাম ঠিক মনে পড়ছে না ভালো ...
# [GPU 1] Chunk 36/157: দাঁড়া দাঁড়া দাঁড়া মনে পড়েছে মনে পড়েছে বুড়ো এবার তার কুটিরের মধ্যে ঢুকে একট...
# [GPU 1] Chunk 38/157: আমি তোকে দিয়ে দিলাম কিন্তু হলদে আর নীল ফল খেলে কি হয় কি হয় এই দেখো এইতো মুশকি...
# [GPU 1] Chunk 40/157: বুড়ো আবার থলির ভিতর হাত ঢুকিয়ে এবার একটা ঝিনুক বার করল সেটা প্রায় হাতের তেলও ...
# [GPU 1] Chunk 42/157: আমার কথা যখন শেষ হয়ে যাবে তখন এই ঝিনুকে শোনা যাবে সমুদ্রের গর্চন তখন আবার তুই ঝ...
# [GPU 1] Chunk 44/157: ফরে ফলমূল আছে তাই না হয় খাবি এখন কানাই রাজি হয়ে গেল তার ইচ্ছে করছিল তখনই লাল ফ...
# [GPU 1] Chunk 46/157: তারপর হাঁটতে গিয়ে দেখল হাঁটলে চলবে না দৌড়াতে হবে সে দৌড় যে কি বেদম দৌড় সে আর...
# [GPU 1] Chunk 48/157: হাঁটতে শুরু করল বাকি পথটুকু এমনিভাবে হেঁটেই যাবে নইলে অন্য পথচারীরা কি ভাববে তাক...
# [GPU 0] Chunk 49/157: একটু মুশকিলেই পড়তে হয়েছিল সিপাহীরা কানাইকে দেখেই তার পথ রোধ করতে গিয়েছিল তাই ...
# [GPU 0] Chunk 51/157: হাতে বল্লম্বালা সেপাইরা ঘোরাফেরা করছে কানাইয়ার ভারী কৌতুহল হলো সে একটা কাপড়ের ...
# [GPU 0] Chunk 53/157: ওষুধের কথাটা বলতে গিয়ে বলল না আশ্চর্য ব্যাপার মন্ত্রী গিয়ে চাঁদনী গাছ নিয়ে এস...
# [GPU 0] Chunk 55/157: বাজার ছাড়িয়ে এসে দেখল একটা পাড়ার মধ্যে এসে পড়েছে এখানে চারদিক থেকে কান্নার আ...
# [GPU 0] Chunk 57/157: তো কোন চিকিৎসা নেই আমায় এখনো ধরেনি রোগে তবে ধরতে আর কতদিন চিকিৎসা নেই বলছো কেন ...
# [GPU 0] Chunk 59/157: পেয়াদারা ভল্লমের খোঁচা মেরে তাতিদের দিয়ে কাপড় বোনায় যারা বোনে না তাদের ওই শু...
# [GPU 0] Chunk 61/157: রাজা চায় তাতিরা সব মরুক তাই তাই ওষুধ এনে সরিয়ে রেখেছে কানাইয়ের মনটা শক্ত হয়ে...
# [GPU 0] Chunk 63/157: বয়স্থা সে যদি রাজা হয় তাহলে দেশের সব দুঃখ দূর হবে এই রাজাকে সরাবার কোন রাস্তা ...
# [GPU 1] Chunk 50/157: নানান রকমের জিনিসের মধ্যে কাপড়ই বেশি আর সেই কাপড়ের বাহার দেখে কানাই তো থ দেশবি...
# [GPU 1] Chunk 52/157: মুখে হাসি নেই কেন লোকটা এপাশে ওপাশে দেখে নিয়ে বলল তুমি বুঝি ভিন দেশের লোক হ্যাঁ...
# [GPU 1] Chunk 54/157: সে গাছ তাহলে গেল কোথায় কানাই উঠে পড়লো তার মনে পড়ে গেছে যে এখানে আসার একমাত্র ...
# [GPU 1] Chunk 56/157: তবে তাতি তো আর এখানে বেশিদিন নেই চারটে করে তাতি রোজ মরছে ব্যারামে দেখো না শশী গে...
# [GPU 1] Chunk 58/157: এ গাছ তো মন্ত্রী মশাই আমাদের দেবেন না কেন দেবে না কেন আমাদের রাজা বড় সর্বনেশে এ...
# [GPU 1] Chunk 60/157: তিন ভাগ যায় ওই রাজকশে তো তাতিরা সব একজোটে রাজাকে হটিয়ে তার ছেলেকে সিংহাসনে বসা...
# [GPU 1] Chunk 62/157: সে যে করেই হোক চাঁদনীর পাতায় এনে দেবে তাতিদের জন্য যে করেই হোক বুড়ো বলে চলল রা...
# [GPU 1] Chunk 64/157: দুঃখ পেতেই জানে আচ্ছা রাজবাড়িটা কোন দিকে বলতে পারো এই যে রাস্তা এটা দিয়ে সোজা ...
# [GPU 0] Chunk 65/157: তোমায় সেখানে ঢুকতে দেবে না পাহারা সেখানে বড় করা কানাই বুড়োর কাছ থেকে বিদায় ন...
# [GPU 0] Chunk 67/157: কোন লোক নেই দেখে কানাই থামলো বাঁদিকে বাগান তাকে চারদিক দিয়ে ঘিরে আছে শ্বেত পাথর...
# [GPU 0] Chunk 69/157: কানাই দেখল সে এক অতিকায় প্রহরীর হাতে বন্দি মহারাজ প্রহরী কানাইকে সোজা নিয়ে গেল...
# [GPU 0] Chunk 71/157: বলবন তার যশোবনকে শুলে ছড়াও ফটকে নতুন প্রহরী মোতায়েন করো এ রাজ্যে কাজে ফাঁকির শ...
# [GPU 0] Chunk 73/157: আগে হ্যাঁ তা বাগানে কি খুঁজছিলি হ্যাঁ কই কিছু খুঁজে নিত শুধু দাঁড়িয়ে ছিলাম ঠিক...
# [GPU 0] Chunk 75/157: এমন হতাশ কানাইয়ের কোনদিন লাগেনি জগাই বাবার কথা মনে করলো তার নীল আর লাল ফল দুটো ...
# [GPU 0] Chunk 77/157: একটানা খটক শব্দে কানাইয়ের চোখে ঘুম এলো আর দশ মিনিটের মধ্যেই কানাই ঘুমে ঢলে পড়ল...
# [GPU 0] Chunk 79/157: কেন কান পাততেই কানাই কারণটা বুঝলো তার ট্যাকে ঝিনুক থেকে একটা শব্দ হাসছে কানাই কা...
# [GPU 1] Chunk 66/157: মতলা মেটে নিয়েছে সে এমনিভাবে হেঁটে গিয়ে যখন ফটক থেকে বিশ হাত দূরে প্রহরী তাকে ...
# [GPU 1] Chunk 68/157: রয়েছে ছোট ছোট ছুচল বেগুনি পাতা আর হলদে ফুল যদি এরই মধ্যে থাকে তাহলে তার কাজ অনে...
# [GPU 1] Chunk 70/157: রাজা কানাইয়ের দিকে চোখ রেখেই পেয়াদাকে জিজ্ঞেস করলেন এটাকে আবার কোত্থেকে পেলি ম...
# [GPU 1] Chunk 72/157: আবার কানাইয়ের দিকে দৃষ্টি দিলেন তোর ব্যাপার কি শুনি তোর নাম কি আগে আমার নাম কান...
# [GPU 1] Chunk 74/157: তিন মিনিটের মধ্যে কানাই দেখল যে সে কারাগারে বন্দি ঘরাতভালা দরজা খড়াঙ শব্দ করে ব...
# [GPU 1] Chunk 76/157: একটা মাত্র খুপরি জানলা সেটা পশ্চিম দিকে হওয়াতে তার ভেতর দিয়ে বিকেলের রোদ এসে প...
# [GPU 1] Chunk 78/157: সে হঠাৎ সজাগ হয়ে উঠলো বাইরে প্রহরী এখনো টহল দিচ্ছে কে যেন এর মধ্যে বাইরে একটা ম...
# [GPU 1] Chunk 80/157: কানাই মন দিয়ে শোন আরো কিছু কথা মনে পড়েছে হ্যাঁ তোর কাছে যে নীল ফলটা আছে না সেট...
# [GPU 0] Chunk 81/157: ফক্কা সেটা বললেই তোকে না আর কেউ দেখতে পাবে না আবার যখন নিজের চেহারায় ফিরে আসতে ...
# [GPU 0] Chunk 83/157: তাকে এক সদাগর এক লক্ষ স্বর্ণমুদ্রা দিয়ে একটা পান্না বিক্রি করে আজ থেকে প্রায় স...
# [GPU 0] Chunk 85/157: ব্যাস কথা শেষ কানাই কানে সমুদ্রের গর্জন শুনতে পাচ্ছে সে ঝিনুকটা আবার ট্যাংকে গুজ...
# [GPU 0] Chunk 87/157: দিয়ে আবার দেখল তারপর মশাল রেখে চাবি দিয়ে ফটক খুলে অতি সন্তর্পণে ভেতরে ঢুকলো তা...
# [GPU 0] Chunk 89/157: মুখে পৌঁছেছে সেই দরজা পেরোতেই কানাই দেখল সে ছাদে এসে পড়েছে পেল্লায় ছাদ এক্ষণে ...
# [GPU 0] Chunk 91/157: ঘুম ভাঙ্গিনী এবার দরজা খুলে অদৃশ্য কানাই ঘরের ভেতরে ঢুকলো ঘরে একটা টিমি জ্বলছে আ...
# [GPU 0] Chunk 93/157: নাক ডাকানি থেকে মনে হয় বাজ পড়লেও তার ঘুম ভাঙবে না কানাই রাজকুমারকে পুরো ব্যাপা...
# [GPU 0] Chunk 95/157: বাবা নিজের ছাড়া আর কারোর ভালো চান না আর নিজের ভালো মানে যত বেশি টাকা আসে কোষাগা...
# [GPU 1] Chunk 82/157: হঠাৎ মনে পড়লো রুপসার রাজা তার ছেলেকে বন্দি করে রেখেছে প্রাসাদের ছাদের কোণের একট...
# [GPU 1] Chunk 84/157: পাওয়া যাবে সেই নিয়ে তো জগাই বাবা কিছুই বললেন না ঝিনুকের ভেতর আবার কথা শোনা গেল...
# [GPU 1] Chunk 86/157: অদৃশ্য হতেই ট্যাগ থেকে নীল ফলটা বার করে কানাই টপ করে মুখে পড়ে দিল তারপর প্রহরীর...
# [GPU 1] Chunk 88/157: পা টিপে টিপে কোন শব্দ না করে দুজন প্রহরীর নাকের সামনে দিয়ে কানাই বেরিয়ে এসে পৌ...
# [GPU 1] Chunk 90/157: হা করে ঘুমাচ্ছে তার নাক দিয়ে ঘরঘর করে শব্দ বের হচ্ছে ঘরের দরজায় একটা বড় তালা ...
# [GPU 1] Chunk 92/157: দরজাটা ভেজিয়ে দিয়ে কানাই এবার খাটের দিকে ঘুরে ফিসফিস করে বলল টক্কা আর অমনি তার...
# [GPU 1] Chunk 94/157: গাছের পাতা আমার চাই শুধু আমার বাবার জন্য নয় তোমাদের এখানে তাতিরা সব মরতে বসেছে ...
# [GPU 1] Chunk 96/157: আসলে সাত বছর আগে এক সদাগর বাবাকে সেটা বেচে সেই থেকে বাবার একটা দিনের জন্য কোন অস...
# [GPU 0] Chunk 97/157: এই শুকনাই এর মোড়ক আচ্ছা একটা কথা বলো দেখি কি রাজা মশাই শোবার ঘরটা কোথায় আমি তো...
# [GPU 0] Chunk 99/157: পড়েছি তখন আর তুমি বন্দি থাকবে কেন রাজবাড়ি ছাড়া তোমার কোন ঠাই আছে হ্যাঁ আছে তা...
# [GPU 0] Chunk 101/157: করতে পারবে না তোমাকে পিঠে করে নিয়ে আমি ঝড়ের বেগে বেরিয়ে যাব কেউ আমাদের নাগাল ...
# [GPU 0] Chunk 103/157: গোপালের মা সেই কথা ভেবেই কানাই আর কিশোরকে বলেছিলেন আমার এখানে থাকার বিপদটা কি তা...
# [GPU 0] Chunk 105/157: কানাই আর রাজকুমার দুজনেই কয়েদি অবস্থা থেকে পালিয়েছে দেখে রাজবাড়িতে হুলুস্থল প...
# [GPU 0] Chunk 107/157: সবুজ সইতে না পেরে কিশোরকে বলল হ্যাঁ ভাই সেই জাদুপান্না না সরাতে পারলে তো আর চলছে...
# [GPU 0] Chunk 109/157: তবে আর কি এইতো সুযোগ কাল ভোরে আমি রাজবাড়ি যাব অদৃশ্য হয় দেখি তোমার বাবার সঙ্গে...
# [GPU 0] Chunk 111/157: উত্তরীয়টা ঘাটের পাশের বেদিতে রেখে রাজা খরম খুলে সিনি দিয়ে এগোলেন গলায় হারের প...
# [GPU 1] Chunk 98/157: ছাড়াও একটা ভয়ানক হিংস্র কুকুর পাহার দেয় আর সে তোমাকে দেখতে না পেলেও তোমার গন্...
# [GPU 1] Chunk 100/157: গোপালের সঙ্গে মিশতে দেন না আমাকে কিন্তু আজ যদি তার কাছে যাই আমি জানি সে আমাকে ফি...
# [GPU 1] Chunk 102/157: নিচে সিঁড়ির মুখে দরজা আর দরজা পেরোলেই বাগান সেইখান থেকেই দেব ছুট গোপালদের বাড়ি...
# [GPU 1] Chunk 104/157: মুখে বলা এক আর কাজে আর এক তিন দিন কেটে গেল তবু কাজ এগোলো না একটুও আর মাত্র দুদিন...
# [GPU 1] Chunk 106/157: যে রাজকুমারের ভাব ছিল সেটা রাজা জানতেন তাই গোপালের বাড়িতেও পেয়াদা পাঠিয়েছিলেন...
# [GPU 1] Chunk 108/157: বাবার রাগ সপ্তমে চড়ে যেতে পারে তাও চেষ্টা করতে ক্ষতি কি তুমি একবার একটু ভেবে বল...
# [GPU 1] Chunk 110/157: একটা বকুল গাছের নিচে দাঁড়িয়ে রইল পূব আকাশে পদ্মের রং ধরেছে কিন্তু সূর্য তখনো ও...
# [GPU 1] Chunk 112/157: রাজার সাত হাত দূরে গলা জলে দাঁড়িয়ে অপেক্ষা করতে লাগলো রাজা যেই ডুব দিলেন অমনি ...
# [GPU 0] Chunk 113/157: প্রহরী বলে ডাকছেন প্রহরী প্রহরী ছুটে এলো প্রহরী প্রহরী কি হলো কি হলো মহারাজ কি আ...
# [GPU 0] Chunk 115/157: সে করে এসেছে কিন্তু এর ফলে রাজার মধ্যে কোন পরিবর্তন এলো কিনা সেটা কি করে বোঝা যা...
# [GPU 0] Chunk 117/157: চোখে তো সেই একই শয়তানের দৃষ্টি কেবল ঠোঁটের কোণে বাঁকা হাসির বদলে আজ প্রচন্ড রাগ...
# [GPU 0] Chunk 119/157: সে হার পাওয়া যায়নি আজ থেকে শাসন হবে আরো দশ গুণ করা যতদিন সেই জাদুকর আর রাজকুমা...
# [GPU 0] Chunk 121/157: একে দেশে মরক তার উপরে রাজার এই মূর্তি সারাদেশ তো ছারখার হয়ে যাবে কানাই তখন মনে ...
# [GPU 0] Chunk 123/157: হঠাৎ চমকে উঠলো তার নাম ধরে কে যেন ডাকছে ক্ষীণস্বরে সে তৎক্ষণাৎ এক থেকে ঝিনুক বের...
# [GPU 0] Chunk 125/157: বুঝলেই বুঝলাম কিন্তু কিন্তু আবার কি হলদে ফলের গুণ কি সেটা তো বললেন না এই রে সেটা...
# [GPU 0] Chunk 127/157: জগাই বাবার নির্দেশ মতো কানাই সকাল থেকেই অদৃশ্য হয়ে বাগানে হাজির হলো তারপর বাগান...
# [GPU 1] Chunk 114/157: জল সেচতে হবে ওই হার আমার ফেরত চাই চাই হাতের মুঠোয় হার নিয়ে রাজবাড়ি থেকে বেরিয...
# [GPU 1] Chunk 116/157: রাজা তখনো আসেননি কানাই পেছনের দিকে এক কোনায় চুপটি করে দাঁড়িয়ে এদিক ওদিক দেখতে...
# [GPU 1] Chunk 118/157: দিয়ে পালিয়েছে আবার আমার ছেলেকে বন্দি দশা থেকে মুক্তি দিয়েছে আমার গলা থেকে আমা...
# [GPU 1] Chunk 120/157: এই ভীষণ কয়েকটা কথা বলে রাজা সিংহাসন ছেড়ে চলে গেলেন কানাই একেবারে মুশরে পড়ল জা...
# [GPU 1] Chunk 122/157: আজ থেকে বাজারে কেনাবেচা বন্ধ সেই সঙ্গে এও ঘোষণা হচ্ছে যে রাজকুমার আর জাদুকরকে যে...
# [GPU 1] Chunk 124/157: রণ্দরমহলের বাগানের ইশান কোণে হ্যাঁ সেই কোণে জলে ঘেরা একটা ছোট্ট দ্বীপে চাঁদনি গা...
# [GPU 1] Chunk 126/157: সে চাঙ্গা হয়ে উঠবেই আচ্ছা আমি আসি ঝিনুকের মধ্যে আবার সমুদ্রের বর্জন কানাই সব ঘট...
# [GPU 1] Chunk 128/157: একটা মানুষ অক্কা পায় আর দ্বীপটাকে ঘিরে আছে একটা পাঁচ হাত ছওড়া পরিখা তাতে কিলবি...
# [GPU 0] Chunk 129/157: খাওয়া শেষ হলে কানাই দুগগা বলে কাজে লেগে পড়লো আজই শেষ দিন আজ তাকে যে করে হোক চা...
# [GPU 0] Chunk 131/157: পাইকে হতভম্ব করে দিয়ে শূন্য দিয়ে সে তলোয়ার নিয়ে বাঁশের সেতুর ওপর দিয়ে দ্বীপ...
# [GPU 0] Chunk 133/157: তীরের বেগে দেখতে দেখতে নন্দীগ্রামে তার বাড়িতে পৌঁছে গেল কানাই বাবা বিছানায় পড়...
# [GPU 0] Chunk 135/157: তুই আমাকে বাঁচালি এ যাত্রায় কানাই বাবাকে বলল তাকে আরেকবার রূপসা যেতে হবে সেখানক...
# [GPU 0] Chunk 137/157: তাতিপাড়ায় ঘরে ঘরে হাসিমুখ দেখতে দেখতে কানাই পৌঁছলো গোপালের বাড়ি কিশোর রয়েছে ...
# [GPU 0] Chunk 139/157: তো সে ওষুধটাকে দাও কিন্তু একটা শর্তে কি কি শর্ত তিনি যেন রোগ সারলেই রাজকার্য ছেড...
# [GPU 0] Chunk 141/157: রাজবাড়িতে শোকের ছায়া পড়েছে রাজার অসুখের একমাত্র ওষুধ চাঁদনির পাতা ভেলকির বসে ...
# [GPU 0] Chunk 143/157: ঠিক সেই সময় গিয়ে উপস্থিত হলো কিশোর আর কানাই ছেলেকে দেখে কাতর কন্ঠে বলে উঠলেন র...
# [GPU 1] Chunk 130/157: দ্বীপের উপরে গিয়ে পড়ে ফলে বেশি একটা সেতু তৈরি হয়ে গেল কুমির বাঁচিয়ে দ্বীপে য...
# [GPU 1] Chunk 132/157: গোপাল কানাইয়ের হাতে গাছ থেকে চেচিয়ে উঠলো চলো যাই ঘরে ঘরে পাতা বিলিয়ে আসি তাই ...
# [GPU 1] Chunk 134/157: খেয়ে নাও বাবা খেয়ে নাও দে দে দে কোন মতে ঘাড় উঁচু করে রস খেয়ে আহ বলে একটা আরা...
# [GPU 1] Chunk 136/157: কিছু ফল আর এক বাটি দুধ রেখে যাস এই খাটের পাশে মনে হচ্ছে মনে হচ্ছে খিদে পাবে কানা...
# [GPU 1] Chunk 138/157: বলল রাজার অসুখ রাজা আমাকে দেখতে চায় আমি যেখানেই থাকি যেন গিয়ে গিয়ে তার সঙ্গে ...
# [GPU 1] Chunk 140/157: ভালো বোনা যায় না নিশ্চয়ই দেবো ভাই তুমি হবে তাতির সেরা তাতি আর তোমার বোনা কাপড়...
# [GPU 1] Chunk 142/157: কোন বাধা দিল না কিশোর আর কানাই সোজা গিয়ে ঢুকলো রাজার ঘরে রাজা সজ্জা নিয়েছেন পা...
# [GPU 1] Chunk 144/157: না বাবা এ হলো রূপসার ভবিষ্যৎ মন্ত্রী মন্ত্রী হ্যাঁ বাবু আমি আমি সঙ্গে করে তোমার ...
# [GPU 0] Chunk 145/157: কথা দেবো দেবো না কেন কথা দেবো দেবো কথা যত যত নষ্টের গোড়া ছিল ওই ওই জাদু পান না ...
# [GPU 0] Chunk 147/157: জায়গায় সিংহাসনে তুই বসবি রূপসার গৌরব ফিরিয়ে আনবি আবার লোকে লোকে ধন্য ধন্য করব...
# [GPU 0] Chunk 149/157: ইতিমধ্যে কানাই নন্দীগ্রামে গিয়ে তার বাবাকে নিয়ে এসেছে কিশোর বলরামকে থাকবার ঘর ...
# [GPU 0] Chunk 151/157: মা তবে শোন বলি একদিনে মনে পড়েছে আরে সেই হলদে ফলটা তোর কাছে আছে তো হ্যাঁ হ্যাঁ আ...
# [GPU 0] Chunk 153/157: জিনুকে আবার সমুদ্রের গর্জন কানাই ঝিনুকটা আবার ট্যাংকে গুজে তার পাশ থেকে হলদে ফলট...
# [GPU 0] Chunk 155/157: গোপালের মা মধুবন্তি মিত্র গোপাল সৌরভ রায় অন্যান্য চরিত্রে বুবাই সাহা মৌমিতা সাহ...
# [GPU 0] Chunk 157/157: আমার...
# [GPU 1] Chunk 146/157: সেই সেই পান্না যাওয়ার পর থেকেই আমার দেহে আর মনে পরিবর্তন শুরু হয়েছে আমি বুঝেছি...
# [GPU 1] Chunk 148/157: তার সৌরভে রাজার শয়ন কক্ষ ভরপুর হয়ে গেল রাজা সেরে উঠলেন একদিনেই তিনদিন পরে যুবর...
# [GPU 1] Chunk 150/157: কানাই রাজসভার মধ্যেই ট্যাগ থেকে ঝিনুক বের করে কানে দিল খ্যান খ্যান করে শোনা গেল ...
# [GPU 1] Chunk 152/157: মঙ্গল কিসে হয় দুষ্টের দমন আর সৃষ্টের পালন কাকে বলে সব জানতে পারবি তখন আর তোকে ব...
# [GPU 1] Chunk 154/157: সন্ডে সাসপেন্সে আজ শুনলেন সত্যজিৎ রায়ের লেখা কানাইয়ের কথা মুখ্য ভূমিকায় কানাই...
# [GPU 1] Chunk 156/157: প্রযোজনা প্যাস্টেল এন্টারটেইনমেন্ট সমগ্র পরিকল্পনা ইন্দ্রানী শেষ হলো সত্যজিৎ রায...
#    ✓ Done in 1m 17s  |  speed 50.07× realtime  |  33897 chars
#
# [4/24]
#    test_004.wav  |  1h 7m 45s  |  163 chunks
# [GPU 1] Chunk 2/163: আরো যথারীতি হাওড়া থেকে আমরা রাতের ট্রেনে চেপে বসেছি চলেছি ছোট নাগপুরের গিরিড়িত...
# [GPU 1] Chunk 4/163: খরচা কিন্তু তোমাদের দুজনের আমি কেবল সঙ্গ দিতে যেতে পারি আর যদি কোন বিপদ আপদ হয় ...
# [GPU 1] Chunk 6/163: জিনিসে নিশ্চয়ই সিটের তলায় ঢুকিয়েই লাগতো হয়তো তারা মধুচন্দ্রিমায় চলেছে তাই এ...
# [GPU 1] Chunk 8/163: চাঁদের স্নিগ্ধ আলো চারদিকে এক রহস্যময় সৌন্দর্য ছড়িয়ে দিচ্ছে যেন পৃথিবীকে মায়...
# [GPU 1] Chunk 10/163: কথার ফাঁকের লক্ষ্য করলাম উল্টো দিকে বসা কম বয়সী ছোকরাটি তার সামনে ধরা ইংরেজি পত...
# [GPU 1] Chunk 12/163: একাই ঘুরছি কারো সঙ্গে না কয়েক মুহূর্তের জন্য তারাত যেন নিজের মনই গভীরে কোথায় হ...
# [GPU 1] Chunk 14/163: বিধাতার লেখা ঠান্ডা হয়ে কে বিধি যেখানে নিয়ে যাবে কারো সাধ্য নেই তা অমান্য করে ...
# [GPU 1] Chunk 16/163: এখন কিন্তু পথ পাথুরে আর দুপাশে ঘন জঙ্গল পিছন দিকে হারিয়ে যাবার পায়ে নিয়েই বুঝ...
# [GPU 0] Chunk 1/163: যেকোনো জায়গায় যেতে রাতের ট্রেনই আমাদের সবচাইতে পছন্দের বেশ খাওয়াদাওয়া সেরে ল...
# [GPU 0] Chunk 3/163: একদিন যাবত পাওনা ছুটি নিয়ে বসে রয়েছে বাসায় আমাদের চট করে শহরের বাইরে যাওয়া হ...
# [GPU 0] Chunk 5/163: জাতিদের মধ্যে একজন মহিলা আর তিনজন পুরুষ রয়েছে এদের প্রতি দুজনের বয়স আন্দাজ ষাট...
# [GPU 0] Chunk 7/163: অর্ধেকটা গুলি কাটিয়ে দিয়ে কিশোরী চোখ পিটিট করে কিছু একটা জুতসই উত্তর দিতে যাচ্...
# [GPU 0] Chunk 9/163: শহর ঘুরে দেখব সে বরঞ্চ অনেক রোমাঞ্চকর বুজরুকি বাদ দিয়ে ট্রেনের ওই মৃদুবন্ধ ঝাঁক...
# [GPU 0] Chunk 11/163: সাধু সন্ন্যাসীর সাথে করেছি নানা জায়গায় কিছু কিছু ক্ষমতাও পেয়েছি সেই সূত্রে সং...
# [GPU 0] Chunk 13/163: রাত নামলেই এক ভয়ঙ্কর নিঃশ্বাস যেন গ্রামটিকে গ্রাস করে রাতের অন্ধকারেই সেখানে যে...
# [GPU 0] Chunk 15/163: বাকি তখনও নতুন বছরের শুরুটা পরিবারের সাথে কাটাবো বলে একটু তাড়াহুড়ো করেই ফিরছি ...
# [GPU 0] Chunk 17/163: শিকড় চারদিক থেকে আঁকড়ে ধরেছে সেই মন্দিরকে ভিতরটা প্রায় অন্ধকার বাইরে তখন প্রচ...
# [GPU 0] Chunk 19/163: কিছু আমায় কাবু করতে পারলো না বাইরের ঠান্ডা হাওয়ার ঝাপটা দিয়ে যাচ্ছে ভেতুরে আম...
# [GPU 0] Chunk 21/163: একবার মনে হলো দূরে যেন কোন অজানা পশু গর্জন করছে আবার মনে হলো যেন অদ্ভুত এক আর্তন...
# [GPU 0] Chunk 23/163: আশেপাশের সবাই নিঃশব্দে দাঁড়িয়ে আছে অপেক্ষায় কিসের অপেক্ষা তা তারাই জানে কিন্ত...
# [GPU 0] Chunk 25/163: তাকে ঘিনে দেখা লোকগুলো এবার একই কাপড়ের হাত ধরে এক মানন রুজু তৈরি করে স্থানটাকে ...
# [GPU 0] Chunk 27/163: দেখে আমার বেশি মজা দিল সকলেই গভীর মনোযোগ দিয়ে তাকিয়ে উঠতাম তার দিকে রাত গভীর থ...
# [GPU 0] Chunk 29/163: মন্দিরের বাইরে গিয়ে বললাম লোকালয়ের সন্ধান প্রয়োজন কারণ কুন্ডিবৃত্তি আগের সন্ধ...
# [GPU 0] Chunk 31/163: তুলে ইশারায় কাছে ডাকলাম কয়েক মুহূর্ত ইতস্তত করে একে একে তারা এগিয়ে এল তাদের দ...
# [GPU 1] Chunk 18/163: যেন আন্চান করে উঠলো সারাদিনের পথশ্রমে আমি এমনিতেই বড় ক্লান্ত হয়ে পড়েছিলাম অন্...
# [GPU 1] Chunk 20/163: বেয়েটা তখন বিকশ কালো অন্ধকারে থাকা ঠিক আজকের রাতটার মতন দেওয়ালে ঠেজ দিয়ে উঠে ...
# [GPU 1] Chunk 22/163: পোশাক পরিহিত একদল মানুষ গোল হয়ে দাঁড়িয়ে আছে তাদের মাঝে জ্বলছে এক বিশাল রঙিন্য...
# [GPU 1] Chunk 24/163: গোল হয়ে দাঁড়িয়ে থাকা লোকগুলোর মাঝখানে গিয়ে উপস্থিত হল তার হাতে ধরা একটি প্রা...
# [GPU 1] Chunk 26/163: মনে হচ্ছে যেন এক অশুভ শক্তির আগমনের প্রকোপে পৌঁছে কিন্তু হঠাৎ সেই সুদর্শন বোধ ফে...
# [GPU 1] Chunk 28/163: চোখ মেলতে দেখি বাইরে ভোরের আলো ফুটছে পাখির কিচিরমিচির এই বোধ করি গুণটা ভেঙে গেল ...
# [GPU 1] Chunk 30/163: পাওয়া যায় কি সেই সন্ধানে বের হতে হবে এমন সময় দেখলাম পিছনের সরু আলপথ ধরে জোনা ...
# [GPU 1] Chunk 32/163: জ্যেষ্ঠ তার বয়স আনুমানিক ষাট পঁয়ষট্টি হবে তাকেই বলেন নেতা বলে মনে হলো তিনিই প্...
# [GPU 1] Chunk 34/163: তিনি একটু হতাশ হলেন যেন তারপর কি ভেবে তার চোখ মুখ উজ্জ্বল হয়ে উঠলো অন্য সঙ্গীদে...
# [GPU 1] Chunk 36/163: না না না তা কেন আমার নাম রঘুনাথ পাশেই আমাদের গ্রাম দয়া করে যদি আপনি আমাদের গায়...
# [GPU 1] Chunk 38/163: মন্দিরকে উত্তরে রেখে সরু আলপথ ধরে আমরা এগিয়ে গেলাম পাশাপাশি দুজনে হাঁটা চলে না ...
# [GPU 1] Chunk 40/163: অনুচারিতার পর রঘুনাথ বললেন আগে বাবার একটু সেবার ব্যবস্থা করি আমি হাত তুলে বাধা দ...
# [GPU 1] Chunk 42/163: উনুন জ্বালাবার জন্যে কাঠ এনে পাশে রাখলো আমি স্মিতভাবে এসে তার দিকে তাকাতে চমকে উ...
# [GPU 1] Chunk 44/163: খাওয়া শেষ করে শুয়েও কেমন ছটফট করতে লাগলাম সবাই তখন যে যার ঘরে দ্বিপ্রাহরিক বিশ...
# [GPU 1] Chunk 46/163: বাবা সে কারণ বলতে একটু সময় লাগবে সে এক বিচিত্র না আপনি যদি দয়া করে আজকের রাতটা...
# [GPU 1] Chunk 48/163: চাপা দিতে হলো ফিরে এলাম নিজের আস্তানায় সেই অসুস্থ গাছের ছায়ায় সন্ধ্যার কিছু প...
# [GPU 0] Chunk 33/163: বেশ বেশ একটা কথা বাবা কালোকে কি কাল রাতে এদিকে আসতে দেখেছেন না আমি তো ঝড়ের বেগ ...
# [GPU 0] Chunk 35/163: কথার মাথামুন্ড কিছুই তখন বুঝতে পারছি না অবাক হয়ে তাকিয়ে আছি দেখে তিনি বললেন আপ...
# [GPU 0] Chunk 37/163: বেড়িয়ে যাওয়ার চেষ্টা করলেও মনে মনে যে একটা অদৃশ্য টান অনুভব করছিলাম না এমনটা ...
# [GPU 0] Chunk 39/163: আমাদের আসতে দেখে আশপাশের ঘরগুলো থেকে অনেকে বের হয়ে গেল আমরা গ্রামের প্রায় মাঝ ...
# [GPU 0] Chunk 41/163: করে দিচ্ছি আমায় আপনি খাওয়াদাওয়া সেরে হাতে একটু ডিস্টার করে নেন ওবেলা না হয় আ...
# [GPU 0] Chunk 43/163: ছেলে রুদ্রাংশ স্নান আন্ধিক সেরে খেতে বসে খিদে থাকলেও তেমন একটা রুচি হলো না কেন জ...
# [GPU 0] Chunk 45/163: বিকেল বেলা পড়ে এলেও বাইরে তখনো বেশ রোদ আমার হাঁক ডাকে রঘুনাথ আর তার স্ত্রী হাত ...
# [GPU 0] Chunk 47/163: দেখো সব খুলে না বললে আমার দ্বারা তোমাদের উপকার হবে কিনা সেটা বুঝবো কেমন করে এবার...
# [GPU 1] Chunk 50/163: হঠাৎ এক অজানা তীঘ্ন শব্দে গায়ের মাটি যেন কেঁপে উঠলো প্রথম রাতে সবাই ভেবেছিল হয়...
# [GPU 1] Chunk 52/163: প্রভাবে অনেকেই অসুস্থ হয়ে পড়লো কেউ কেউ তো রাত্রে ভয় চিৎকার করে উঠতে লাগলো আপন...
# [GPU 1] Chunk 54/163: হয়ে যাবে এবার শুধু আতঙ্ক নয় গ্রামের অনেকেই এর ফলে অসুস্থ হতে শুরু করল সকলের শর...
# [GPU 1] Chunk 56/163: সেটাও আর ভুল হয়ে গেল ঠিক দু মাস পরে আবার গত পরশু রাত থেকে শুরু হয়েছে এবার যেন ...
# [GPU 1] Chunk 58/163: কয়েকজন এখনো তাদের ক্রমশ শুকিয়ে যাওয়ার জন্য নিয়ে নিচে রয়েছে তা আপনি চায় দেখ...
# [GPU 1] Chunk 60/163: বের করে সেখানে যা করার তা করতে হবে রাত গভীর হচ্ছিল আমি সকলকে বিদায় দিয়ে রঘুনাথ...
# [GPU 1] Chunk 62/163: কালো আঁধার গ্রামটিকে ঢেকে দিল নিজের গাত্র বন্ধন করে আমি আমার ঝোলা লাঠি আর একটা ল...
# [GPU 1] Chunk 64/163: তারানাথ এবার থামলো পাশে রাখা ঘটিটা তুলে পুরোটা নিয়ে গলায় খানি করে নিয়ে বলল আহ...
# [GPU 0] Chunk 49/163: আমাদের এই প্রাদুর্ভাবে বরাবরই শান্ত বাবা একে অপরের সুখে দুঃখে সবাই পাশে থাকে মোদ...
# [GPU 0] Chunk 51/163: থাকলো আতামুখে সকাল হইতে আবার সব চালাবে শব্দটা কিসের বা কোথা থেকে এলো তা নিয়ে বি...
# [GPU 0] Chunk 53/163: সেই রাতে শব্দও আর হলো না এরপর শব্দটা কিছুদিনের জন্য একেবারেই থেমে গেল হারিজাবাজ ...
# [GPU 0] Chunk 55/163: তিনি যথামিল্য যোগ্য করে ভোটার ডানটাকে শুদ্ধ করলেন হারিয়ে যাওয়া যুবকদের মৃত ধরে...
# [GPU 0] Chunk 57/163: যেদিন প্রথম ওই বিকট শব্দ শুনেছিলে সেদিন কি চন্দ্রগ্রহণ ছিল হ্যাঁ তাইতো কিন্তু আপ...
# [GPU 0] Chunk 59/163: সকলে নানা করে উঠলো রঘুনাথের স্ত্রী অনুনয়ের সুরে বলল আপনি যাবেন কিন্তু কেন বাবা ...
# [GPU 0] Chunk 61/163: দিনটা মানসিক প্রস্তুতিতে কেটে গেল কেবলই মরতে লাগলো দুর্যোগের সেই রাতে মন্দিরে শু...
# [GPU 0] Chunk 63/163: বললাম যাই ঘটুক না কেন এই রেখা কোনভাবেই পার করবে না আমি ফিরে না আসা পর্যন্ত কেউ এ...
# [GPU 1] Chunk 66/163: কে জানে আমিও বললাম কিন্তু আপনি দিনের বেলা না গিয়ে ওই গভীর অনেক সন্ধেবেলা কেমন হ...
# [GPU 1] Chunk 68/163: আমার আশ্রয়স্থল সেই পুরনো মন্দিরের চাতালে গিয়ে পৌঁছলাম মন্দিরটি প্রায় ধ্বংসপ্র...
# [GPU 1] Chunk 70/163: মন্ত্র পাঠ চারপাশের বাতাস সমস্যা ভারী হয়ে গেল মন্দিরের কাছেই কোথা থেকে বিকট তীঘ...
# [GPU 1] Chunk 72/163: কালো জাদুর কারণে আমি আরো জোরে মন্ত্র পাঠ শুরু করলাম মন্ত্রের প্রতিটা শব্দ রাতের ...
# [GPU 1] Chunk 74/163: সময় যেন সেখানেই থমকে গিয়েছে বাইরে ঘন ঘন বিদ্যুৎ চমকাচ্ছে বুঝতে পারলাম আবার বুঝ...
# [GPU 1] Chunk 76/163: কারণের অন্তর্ভুত ভস্ট মুঠো করে ফেলে দিলাম যোগ্যগুণের প্রজ্জ্বলিত অগ্নির মধ্যে ছা...
# [GPU 1] Chunk 78/163: তাকে একটু শান্ত করলাম রুদ্রাংশের বক্তব্য শোনা দরকার না হলে এই রহস্য রহস্যই থেকে ...
# [GPU 1] Chunk 80/163: হাসতে হাসতে সোনা আসছে তবে আগের সেই গম্ভীর আর অস্পষ্ট ভাবটা ততটা নেই আমি সেদিন রা...
# [GPU 0] Chunk 65/163: তবে কে যেন বলছিল বাজে সময় নষ্ট না করে ঘুমিয়ে নিতে বুজরুকি বাদ দিয়ে ট্রেনের মৃ...
# [GPU 0] Chunk 67/163: অতি সাধারণ একটা জঙ্গল মাত্র যাই হোক ভেতরে পড়ছি চারপাশে যেন অদ্ভুত নীরবতা ছড়িয়...
# [GPU 0] Chunk 69/163: বাতাসে ভাসছে এক অদ্ভুত ধরণের গন্ধ আমি সেখানেই বসে পড়লাম হোমকুন্ড নির্মাণ করে তা...
# [GPU 0] Chunk 71/163: মুখ চোখ দেখা যাচ্ছে না বটে কিন্তু তার তীব্র বিস্তারটি যেন আমাকে সম্মানিত করতে চা...
# [GPU 0] Chunk 73/163: কালো ছায়াটি এবার মানুষের মত চিৎকার করতে লাগলো অস্পষ্ট গম্ভীর ও চাপা সারের যে চি...
# [GPU 0] Chunk 75/163: বাইরে প্রচন্ড ঝড় শুরু হলো ঘন ঘন বাজতে পড়তে লাগলো আর এক একটা বিদ্যুতের চমক যেন ...
# [GPU 0] Chunk 77/163: তোমায় দেখতে চাই আমার অনুমান ঠিক কিনা সেটা মিলিয়ে নিতে দাও আমার অনুমানই ঠিক মন্...
# [GPU 0] Chunk 79/163: শুধরে দিও বরং তুমি আর কয়েকজন মিলে বোধহয় কোন তন্ত্র প্রক্রিয়া করতে চেয়েছিলে ক...
# [GPU 0] Chunk 81/163: আমাকে বিশ্বাস করবে কিনা সেই সিদ্ধান্তে পৌঁছাতে তার কিছুটা সময় অবশ্যই প্রয়োজন আ...
# [GPU 0] Chunk 83/163: হাতের তালুন মতনে দিয়ে আমি চিনি ছোটবেলায় দেখেছি এই মন্দির ছিল নৃসিংহ ও কাদিদেবী...
# [GPU 0] Chunk 85/163: কালের অতলে হারিয়ে যেতে শুরু করল এই মন্দির সমস্ত জৌলুস হারিয়ে এক খন্ড হরে পরিণত...
# [GPU 0] Chunk 87/163: শেষের দিকে দেখলাম মরা হয়েছে সাতদিন ধরে পূজার পর যন্ত্রগ্রহণের রাতে এক বিশেষ যজ্...
# [GPU 0] Chunk 89/163: তারপর বলো পূজাবিধিতে লেখা ছিল এই কাজে পূজারী ছাড়া প্রয়োজন আরো সাতজন যুবকের তাদ...
# [GPU 0] Chunk 91/163: আমরাই সেই শব্দ সৃষ্টি করলাম পরপর সাত দিন সবাই খুব ভয় পেল গোটা গ্রামে শোরগোল পড়...
# [GPU 0] Chunk 93/163: তারপর আমার আর ভরসাই ছিল না সম্পূর্ণ বিধি মেনে আমরা আমরা কাজ করে চলেছিলাম কিন্তু ...
# [GPU 0] Chunk 95/163: সেই মুহূর্তে মাথার মধ্যে একটাই চিন্তা কাজ করল তাহলে কি আমাদের এতদিনের চেষ্টা বৃথ...
# [GPU 1] Chunk 82/163: চিন্তিত মুখে বলল আমার দোষেই সব হয়েছে ঠাকুর মশাই আমিই দায়ী সেই বিচার আমার উপর ছ...
# ...
# [GPU 0] Chunk 81/133: বাবা দাও এই কোটায় লাগবে আমার এই তোরে কে কে শপিং এ যাবি চল চল চল চল চল চল চল সবা...
# [GPU 0] Chunk 83/133: কিভাবেই ধরে রাখিস সারাজীবন...
# [GPU 0] Chunk 85/133: আমি এটা নিতে পারবো না ছোটবেলা একবার চুরি ভেঙেছিল অনেক কান্নাকাটি করেছিলে সেদিন ক...
# [GPU 0] Chunk 87/133: কি শপিং করেছিস ওটা দেখাই কি সুন্দর আমাকে জোর করে কিনে দিয়েছে আমি একদম নিতে চাইন...
# [GPU 0] Chunk 89/133: না না না না না না না না না না না না না না না না না না না না না না না না না না না...
# [GPU 0] Chunk 91/133: না না না না না না না কিরে জুলি সারা বাড়িতে এত জায়গা থাকতে তুই আমার পায়ের ঘরে ...
# [GPU 0] Chunk 93/133: তোরা কি মনে করছোস আমার কান দুইটা ঠিকমত কাম কর খাওয়ানোর সময় তো কম খাবি না চাচা ...
# [GPU 0] Chunk 95/133: তুমি না এই হাসুর সাথে এই মাইয়াডারে চলতে দিও না দূরে রাইখো দেখছো কেমন কইরা লাখ ট...
# [GPU 1] Chunk 82/133: তাড়াতাড়ি গাড়িতে উঠ এই উঠো আরে তাড়াতাড়ি করো চল তুই হাসানের সাথে বাইকে আয়...
# [GPU 1] Chunk 84/133: সবাই বাসায় গেল তুই আমাকে এখানে নিয়ে আসছিস কেন তোর কি এটা খোলা...
# [GPU 1] Chunk 86/133: না কিরে...
# [GPU 1] Chunk 88/133: আমার জন্য এই এগুলো রাখ হাত দে বাহ কি নরম হাত খুব সুন্দর লাগছে...
# [GPU 1] Chunk 90/133: মানে আমার একটা বন্ধু দরকার ডোন্ট টেল মি তুমি বিয়ে করতে চাও নাকি আমি তোর বিয়ের ...
# [GPU 1] Chunk 92/133: তুই মনে হয় নাস্তা করস নাই সকালে নাস্তা খাইছোস মাথাটা ঠান্ডা কর যা নাস্তা করে যা...
# [GPU 1] Chunk 94/133: কাম কর আচ্ছা করতেছি বলতে বলতে একটা পর পুরুষের লগে মোটরসাইকেল ওইটা বসে এলাকার মধ্...
# [GPU 1] Chunk 96/133: আর লিলি ছোটবেলা থেকে একসাথে বড় হইছে হাসুলির কাছে পরপর শৈল কেমনে তারপরেও ভাবি এক...
# [GPU 0] Chunk 97/133: ইঙ্জিনিয়ার কইতে...
# [GPU 0] Chunk 99/133: ঠিক আছে ভাইজান আমি তো এখন গেলাম এক মিনিট বলো আব্বার কবি না লিসেস ফর ইউ বেবি কাল ...
# [GPU 0] Chunk 101/133: দাও কাঁদতে দাও ফুলটা তো দিয়ে দিলাম যদি আব্বা দাড়া কইরা দেয় তাহলে জুতার বাড়ি ...
# [GPU 0] Chunk 103/133: হাসান প্রেম জীবন একবারই আসে সেটা ভাঙলে কখনো জোড়া লাগে না ভাঙলো কেন নিজেকেই প্রশ...
# [GPU 0] Chunk 105/133: পড়েছি ততবারই আমি সিদ্ধান্ত নিয়েছি আমি তোর থেকে দূরে থাকবো কারণ আমি বেহাইয়া না...
# [GPU 0] Chunk 107/133: তুই পাগল মাথা নষ্ট হয়ে গেছে তোর হ্যাঁ আমার মাথা নষ্ট হয়ে গেছে এটা দেখে যে তুই ...
# [GPU 0] Chunk 109/133: আমাকে বুড়ি বলবি না ওকে ফাইন মায়ের কথা ভাবনা প্লিজ মা পড়ে দিছে মা দিছে না প্লি...
# [GPU 0] Chunk 111/133: কিরে...
# [GPU 1] Chunk 98/133: কি হলো ভাইজান আপনি আমারে এই জায়গায় ডাকলেন তোর সাথে একটু প্রাইভেট কথা আছে হুম আ...
# [GPU 1] Chunk 100/133: আমার প্রেমে এটা তাড়াতাড়ি হয়ে যায় যা এই আব্বু এদিকে আয় ভাইজান জুলি তোর কেমন ...
# [GPU 1] Chunk 102/133: তুমি নিয়ে খাও দে...
# [GPU 1] Chunk 104/133: জব থিসিস হুট করে খুব প্রেসার চলে আসা আমার উপরে কন্টাক্ট করতে পারিনি তুই তো কন্টা...
# [GPU 1] Chunk 106/133: তুই তো আমাকে লিখেছিস আমি যেন এখন প্রেম ট্রেম নিয়ে না ভাবি তুই অন্য কাউকে ভালোবা...
# [GPU 1] Chunk 108/133: এটা নিয়ে এটা তো এটা আমি তোর জন্য কিনেছিলাম রাইট তুই যাকে ভালোবাসিস তুই তাকে এটা...
# [GPU 1] Chunk 110/133: কিছু ঠিকঠাক হয়ে যায় তাহলে আমি চলে যাচ্ছি তুই কেন যাবি বাড়িটা তো তোলো একই বাড়...
# [GPU 1] Chunk 112/133: আপু হুম হাসান ভাই কোথায় কোন দিকে যেন গেছে তোর দুলাভাই খুঁজতে গেছে চলে আসবে হাসা...
# [GPU 0] Chunk 113/133: আপু হাসান ভাইকে একটু ডাকুন না প্লিজ আরে চলে আসবো তো এখনই ওই যে লিলি চলে আসছে...
# [GPU 0] Chunk 115/133: বড় অন্যায় করে ফেলছি রে তোর সাথে হাসান ভাই যে চিঠিগুলো দিত তোকে দেওয়ার জন্য আম...
# [GPU 0] Chunk 117/133: হাসো আমি তোকে অনেক ভালোবাসি অনেক অনেক অনেক ভালোবাসি এই চিঠি আমাদের ভালোবাসার দলি...
# [GPU 0] Chunk 119/133: আমি এতটা বছর ওকে ঘৃণা করে এসেছি লিলি তোদের রিলেশনশিপটাতে আমি অনেক জেলাস ফিল করতা...
# [GPU 0] Chunk 121/133: কে এরকম কিপটামি করবা আচ্ছা নিজের মাইয়ার বিয়া তাও কিপটামি এখন খবর দাও তোর সাথে ...
# [GPU 0] Chunk 123/133: জীবনের প্রথম একটা দুর্দান্ত সাহসিকতার কাজ করে ফেললা হ্যাঁ লা তোর ওই হাসি দেখে যা...
# [GPU 0] Chunk 125/133: তুই তো এমন কেউ যার সাথে কখনো রাগ করে থাকে আমাকে বিয়ে করবি তোকে বিয়ে করার সাধ্য...
# [GPU 0] Chunk 127/133: ভালোবাসি ভালোবেসেছিলাম ভালোবাসো হয়েছে আর প্রমাণ করতে হবে না বাড়ি চল মনে বিয়ে ...
# [GPU 0] Chunk 129/133: দেয়া নম্বরে তোর ওই হাসি দেখে যায় একে একে সব অভিমানেরা তুই তো এমন কেউ যার সাথে ...
# [GPU 0] Chunk 131/133: সাথে যাব বহুদূর ওদের কি সুন্দর বানিয়েছে তাই না পাশাপাশি দুজনকে সুন্দর মানালেই জ...
# [GPU 0] Chunk 133/133: তুমি আমার সুখের স্বপ্ন ঠিকই করছো কি হইছে বল কিচ্ছু হয় নাই হাতটা পর্যন্ত ধরা হয়...
# [GPU 1] Chunk 114/133: সরি কেন আপনি অনেক বড় ভুল করে ফেলছেন লিলি তুই আমাকে মাফ করে দে আমি অনেক...
# [GPU 1] Chunk 116/133: এই বুড়ি আমি চলে যাচ্ছি কিন্তু তোর দেওয়া অ্যালবামে ভরা আমাদের স্মৃতিগুলো নিয়ে ...
# [GPU 1] Chunk 118/133: স্বপ্ন পূরণ কর আমি তোর জন্য সারাজীবন অপেক্ষা করবো তোর বুড়ি আর হাসান ভাইয়ের এড্...
# [GPU 1] Chunk 120/133: তুই জানিস তো তুই কি করে ফেলেছিস আপা হাসান কোথায় আমি ওকে ভীষণ কষ্ট দিয়ে ফেলেছি ...
# [GPU 1] Chunk 122/133: কি হইছে হাসান রাগ করে বাড়ি থেকে চলে গেছে এই লিলি যা তো যা ওই নানা ভাই যাও আর হা...
# [GPU 1] Chunk 124/133: অভিমানের আয় না তুই তো এমন কেউ যার সাথে কখনো রাগ করে থাকা যায় না তোর ওই হাসি রে...
# [GPU 1] Chunk 126/133: এতদিন পোস্ট অফিস আটকে ছিল তোর মানে একটা চিঠিও তুই পড়িস নি আমি শুধু তোকে...
# [GPU 1] Chunk 128/133: তুই তো এমন কেউ যার সাথে কখন রাই করে থাকা যায় লাইফ বয় ভাইরাস ফাইটার যা ভাইরাসের...
# [GPU 1] Chunk 130/133: তোমার প্রতি আমার প্রথম অনুভূতিগুলো কাগজেই থাকুক পুরনো হোক মসৃণ হোক বৃদ্ধ হোক তবু...
# [GPU 1] Chunk 132/133: আপনার সাথে আমার দেখাই হতো না আমাদের বিয়ের ডেট নিয়ে আলাপ হয়েছে তোর ব্যাপ্রাইজ ...
#    ✓ Done in 54s  |  speed 61.34× realtime  |  21230 chars
#
# [24/24]
#    test_032.wav  |  43m 14s  |  104 chunks
# [GPU 1] Chunk 2/104: হে আপু বলো একটু এদিকে আয় তো শোন নাস্তা রেডি আছে রিপন রুপকে তুলে সবাই মিলে নাস্ত...
# [GPU 1] Chunk 4/104: তাহলে তুমি যে এতটা পথ ফেটে যাবে আবার অভ্যাস আছে সময় নেড়ে দেরি হয়ে যাচ্ছে আমি ...
# [GPU 1] Chunk 6/104: রোজ রোজ একই নাস্তা খেতে আর ভালো লাগতেছে না নাস্তা যে খেতে আবার তো সেটার জন্যই শু...
# [GPU 1] Chunk 8/104: মহিলার সুযোগ এত দূর তো হয়ে গেল দেখবো কেমনে আসলে অফিসে টাইম ওভার হয়ে গেছে তো তা...
# [GPU 1] Chunk 10/104: চাও বাইরে দেখ তো বলছি...
# [GPU 1] Chunk 12/104: আচ্ছা রাখি ঠিক আছে ভ্যারি কম কি হয়েছিলেন বাড়ি এলাম তো টাকা নিতে আসছে ওনাকে বলে...
# [GPU 1] Chunk 14/104: স্যার আপনাকে একটু ডাকছি ঠিক আছে তুমি যাও না স্যার আমাকে ডেকেছেন আসুন কখন আসলেন...
# [GPU 1] Chunk 16/104: সেটা যদি আমি বলে দেই তাহলে আপনাকে কেন রেখেছি সরি স্যার আসলে একটু পারিবারিক চাপে ...
# [GPU 0] Chunk 1/104: রাইসা রাইসা...
# [GPU 0] Chunk 3/104: এই একশত টাকা রিপনা রুপমকে দিয়ে বলিস ভাগ করে নিতে কিন্তু আপু ওদের পঞ্চাশ টাকা কর...
# [GPU 0] Chunk 5/104: এক দুই তিন ঢাকায় জমি জিতে নিন একশত ক্যাশব্যাক সহ বিশ কোটি টাকার পুরস্কার...
# [GPU 0] Chunk 7/104: এটাকে ভালো থাকা বলে আপু যে সকাল থেকে রাত পর্যন্ত এতটা কষ্ট করে কাদের জন্য করে আম...
# [GPU 0] Chunk 9/104: সমস্যা তো একটাই বাড়ি ভাড়া এই মাসের বাড়ি বাড়ি এখনো দেয়নি গত মাসের বাড়ি বাড়...
# [GPU 0] Chunk 11/104: এলো আপু তুই কই আমি তো অফিসে কেন রে কোন সমস্যা আমার তো ডাক্তার দেখাতে হবে টাকা লা...
# [GPU 0] Chunk 13/104: আচ্ছা ঠিক আছে উনাকে বল আমি রাতে অফিস শেষ করে বাসায় এসে উনার সাথে কথা বলবো আচ্ছা...
# [GPU 0] Chunk 15/104: স্যার দশ টা পঁচিশ মিনিটে অফিস কি দশটা পঁচিশ থেকে শুরু হয় প্রতিদিন লেট করে আসলে ...
# [GPU 1] Chunk 18/104: করেছে কবে আমার একটা চাকরি হলেই বিয়ে করবো তুমি চাকরি পাবে কবে আমার বাসা থেকে বিয...
# [GPU 1] Chunk 20/104: যাব তোমাকে বাসায় পৌঁছে দেই চলো আচ্ছা ঠিক আছে চলো আপু তোমার রাতে তো দেরি হলো কেন...
# [GPU 1] Chunk 22/104: তুই করিসটা কি হ্যাঁ একটু রান্না করে রাখতে পারলি না কি রান্না করবো বাসায় তো চাও ...
# [GPU 1] Chunk 24/104: না তো আমার কাছে টাকা নাই টাকা দিয়ে কি করবা কিতা লাগছে তোদের তো আমারও লাগছে রাইস...
# [GPU 1] Chunk 26/104: বাজার আনতে গেছে বাজার আনতেই যামু আপনি আমার সামনে দাঁড়ালেন কেন তোমার সাথে একটা ক...
# [GPU 1] Chunk 28/104: রাইসা জানতো আমি তোমার সাথে লাইফ করি শোনো হ্যালো আপু তুমি না বলছিলে ডাক্তার দেখান...
# [GPU 1] Chunk 30/104: হ্যালো আঙ্কেল আসসালামু আলাইকুম ওয়ালাইকুম আসসালাম বাড়ি ভাড়া টাকা আঙ্কেল আর দুই...
# [GPU 1] Chunk 32/104: আচ্ছা আপনি না গত মাসও অ্যাডভান্স টাকা নিয়ে গেলেন হ্যাঁ প্রতি মাসে আপনাকে এরকম অ...
# [GPU 0] Chunk 17/104: থাকবে স্যার প্লিজ স্যার আমাকে আরেকটা সুযোগ দিন মনে রাখবেন এটাই আপনার শেষ সুযোগ জ...
# [GPU 0] Chunk 19/104: গোল্ড ড্রিং আচ্ছা গোল্ড ড্রিং কিপ করবো তিনদিন পর কিন্তু আমার বার্থডে আচ্ছা বাবা ...
# [GPU 0] Chunk 21/104: রাস্তাঘাট তো ভালো না তুমি যে অফিস থেকে তো রিলেট করে আসো যদি কোন প্রবলেম হয় এত চ...
# [GPU 0] Chunk 23/104: দেখি আমি কোথাও বাকি নিতে পারিনি দেখো তোর কাছে একটা টাকা আছে...
# [GPU 0] Chunk 25/104: আপুকে আর কত বলবো আপুর পক্ষে আর সবদিকে সামাল দিয়ে সম্ভব হচ্ছেন আমার চাকরি হলে আম...
# [GPU 0] Chunk 27/104: না সরেন তাহলে কিন্তু আমি লোকডাউন প্লিজ কথাটা শোনো না কথাটা বলেই আমি চলে যাব আচ্ছ...
# [GPU 0] Chunk 29/104: তুই রাখ আমি স্যারের সাথে কথা বলে দেখছি যা করো তাড়াতাড়ি করো আমার ডাক্তার দেখাতে...
# [GPU 0] Chunk 31/104: স্যার আসবো আসুন তোর কি সমস্যা স্যার আমার ছোট ভাইটা অসুস্থ তো আমি কি করতে পারি ডা...
# [GPU 1] Chunk 34/104: আমারে...
# [GPU 1] Chunk 36/104: আপু কল করছে যাও একটু কথা দেই হ্যাঁ আপু বল রুপম তোর নগদ একাউন্টে টাকা গেছে আসছে ম...
# [GPU 1] Chunk 38/104: আগেই বাকি টাকা দেন এমনিই তো মালামাল তুলতে পারতাছি না আবার বাকি চাচ্ছেন মিলন ভাই ...
# [GPU 1] Chunk 40/104: আব্বু লন্ডন থেকে বেশ ভালো ভাইয়া বিয়ের পর আমাকেও লন্ডন নিয়ে যাবে বাহ বেশ ভালো ...
# [GPU 1] Chunk 42/104: আমার কোন আপত্তি নেই তবে হ্যাঁ বিয়ের পরে তোকে রিপনের বাসায় গিয়ে উঠতে হবে কিন্ত...
# [GPU 1] Chunk 44/104: কথা বলতে রাজি না হয় তাহলে চলে যাব আপু কি রাজি হবে আমি তো নিজেই রাজি না আপনি এখা...
# [GPU 1] Chunk 46/104: আপনারা যদি রাজি থাকেন তাহলে আমি রাইসাকে বিয়ে করতে চাই আপু বিশ্বাস করেন আমি রাইস...
# [GPU 1] Chunk 48/104: রাইসা আমি বলছিলাম আপনি আপনি আমার নাম্বার পেছেন কোথায় আমরা একই ভার্সিটিতে পড়াশো...
# [GPU 0] Chunk 33/104: নাকি বোঝার চেষ্টা করেন না আপনি কি এই অফিসে কাজ করার জন্য এসেছেন নাকি প্রতি মাসে ...
# [GPU 0] Chunk 35/104: হ্যাপি বার্থডে ডিয়ার থ্যাঙ্ক ইউ আমার গিফট কোথায় গিফট আপু টাকা পাঠালে তোমাকে নি...
# [GPU 0] Chunk 37/104: সত্যি বলতেছো চলো চলো মিলন ভাই আমাকে দুই কেজি চাল আর এক কুয়া ডাল দিবেন আগে বাকি ...
# [GPU 0] Chunk 39/104: পার্সেন্ট ক্যাশব্যাক সহ বিশ কোটি টাকার পুরস্কার তোমার ভাইকে আমাদের সঙ্গেও মেনে ন...
# [GPU 0] Chunk 41/104: তুমি চাইলে আমার অফিসে জয়েন করতে পারো ভাইয়া তুমি বিয়ে কবে করবা কেন রে তোরা বিয...
# [GPU 0] Chunk 43/104: আপনি আপনি শেষমেষ বাসা পর্যন্ত চলে আসছেন তোমার আপুর সাথে একটু কথা বলতে আসছি আপু ক...
# [GPU 0] Chunk 45/104: কত বড় সাহস বাসায় পর্যন্ত চলে আসছে বসো বলো কি বলতেছো আপু আমি রাখি আমি আর রাইসা ...
# [GPU 0] Chunk 47/104: আমার এখানে ছিল তাহলে কে...
# [GPU 1] Chunk 50/104: কিরে এভাবে তাকিয়ে আছোস কেন ভাইয়া উনি কে উনি তোর ভাবী ভাবী মানে ভাবী মানে ওর না...
# [GPU 1] Chunk 52/104: খুব সুন্দর জবাব পেয়েছি ভাইয়া ওকে ফাইন এখন সামনে দেখে সর আমাদের বিরাট...
# [GPU 1] Chunk 54/104: এই তুমি কে আল্লাহ আমারে এমন বানাইছে এটা আমার কি দোষ আপনাদের যদি একটা মাইয়া হয়ে...
# [GPU 1] Chunk 56/104: মিথিরা আমি কিন্তু তোমার কথা মতো তোমার ভাইকে বলেছি আমার আম্মা বিদেশে থাকে তুমি যদ...
# [GPU 1] Chunk 58/104: এখন তুই এটা কি বললি ও যা বলছে ঠিকই তো বলছে আপু তুমি চলো তো ওদের সাথে কথা বলে নিজ...
# [GPU 1] Chunk 60/104: আমরা বিয়ে করবো না করবো বছর খানিক যাক তারপর তোমার চাকরি হবার পরেও তুমি আমাকে অপে...
# [GPU 1] Chunk 62/104: কাম সারছে এখন কি হবে ও হচ্ছে রিপন আমার একমাত্র ছোট বোনের জামাই আর রিপনের বাবা মা...
# [GPU 1] Chunk 64/104: তুমি এই চেয়ারটাতে বসো স্যার আপনি কি বুঝছেন আপনার চেয়ারে আমি বসবো হ্যাঁ এখন থেক...
# [GPU 0] Chunk 49/104: আপু তুমি ওই ছেলের কথা বিশ্বাস করো না তো আচ্ছা রাকিব ছেলে কেমন রে ভালো কিন্তু আমি...
# [GPU 0] Chunk 51/104: ভাইয়া তুমি যে বিয়ে করছো আপু জানে না পুলিশ জানে না ওর ভাইয়া বলল তাই বিয়ে করেছ...
# [GPU 0] Chunk 53/104: কি হয়েছে রাইসা তোর মন খারাপ কেন আপু রিপন ভাই রিপনের কি হইছে রিপন ভাইয়া বিয়ে ক...
# [GPU 0] Chunk 55/104: আমার বাপ মায়ে কিছুই করে নাই আমি হে মাইয়া তুমি না আপনার জীবন নষ্ট করছো আমার মাই...
# [GPU 0] Chunk 57/104: কালকে বাসা খুঁজতে যাও রিপন তুই নাকি বিয়ে করছিস তোর নাম মিথিলা আমি আজকে বিয়ে কর...
# [GPU 0] Chunk 59/104: এখন একটু হাসো প্লিজ কি ব্যাপার তোমাকে আজকে তো ফুসফুসি লাগতেছে সরি আমার চাকরি হয়...
# [GPU 0] Chunk 61/104: কোথায় সবাই আসসালামু আলাইকুম ওয়ালাইকুম আসসালাম সবাই এখানে আসো সবার সাথে পরিচয় ...
# [GPU 0] Chunk 63/104: আরুল তুমি রিপন কে অফিসের যাবতীয় ফাইল পত্র বুঝিয়ে দিও ঠিক আছে জি স্যার রিপন তুম...
# [GPU 0] Chunk 65/104: গুলো আমাদের নতুন এমডিকে বুঝিয়ে দাও জি স্যার স্যার এটা আমাদের কমার্শিয়াল সাইড এ...
# [GPU 0] Chunk 67/104: ভাইয়ের এখন আর আমার টাকা প্রয়োজন নেই ওর ভাই এখন মস্ত বড় অফিসার ঠিক আছে আপনি যা...
# [GPU 0] Chunk 69/104: কি হইছে তোমার তোমার কি সংখ্যা না না কিছুই না তাহলে তোমার ছেলে এখন মলিন হয়ে আছে ...
# [GPU 0] Chunk 71/104: আমার বড় বোন আছিল না ভাই তোমার এখানে আছি বাবা রুপম ভাইয়া তুমি ওকে বিয়ে করে ফেল...
# [GPU 0] Chunk 73/104: বাবা...
# [GPU 0] Chunk 75/104: তোমার জন্য অনেক কষ্ট লাগতেছে কাঁদিস না কালকে রাকিবকে একসময় করে বাসায় আসতে বলিস...
# [GPU 0] Chunk 77/104: আরে তুমি ও তো আমাদের বাসায় কাজের মেয়ে তা জানি তুমি একটা কর্পোরেট জব ছেড়ে অন্য...
# [GPU 0] Chunk 79/104: কি সংসার...
# [GPU 1] Chunk 66/104: আর স্যার বাকি ফাইলগুলো আপনি পড়লেই বুঝতে পারেন তারপরও যদি কিছু বুঝতে না পারো পার...
# [GPU 1] Chunk 68/104: ভাবতাম একটা মানুষ তার ভাই বোনের জন্য এত কিছু করে কি ওর ভাই বোনেরও অনেক লাকি জোর ...
# [GPU 1] Chunk 70/104: তেমন কিছু হয় না আচ্ছা তুমি বসো আমি তোমার জন্য এক গ্লাস পানি নিয়ে আসি...
# [GPU 1] Chunk 72/104: যে আপা আমাদের কথা চিন্তা করে বিয়ে করলো না একটা সংসার করলো না সারাজীবন আমাদের কথ...
# [GPU 1] Chunk 74/104: অপু তোমার কি খুব কষ্ট হচ্ছে জীবনে এত কষ্ট করেছি যে এখন কোন কষ্ট কে কষ্ট মনে হয় ...
# [GPU 1] Chunk 76/104: না বলে চলে আসলা যে তোকে খুব দেখতে ইচ্ছা করছিল তাই না বলেই চলে আসলাম ভাই আসসালামু...
# [GPU 1] Chunk 78/104: তুমি চাকরি খুঁজে পাচ্ছিলে না সেটা আমাকে বলতে আমার অফিসে জয়েন করতে তাই বললে মানু...
# [GPU 1] Chunk 80/104: আমি কি করবো রাইসা এমন কেন করছিস বোন আমি তোমাকে রেখে কোথাও যাব না আপু আমি কিন্তু ...
# [GPU 0] Chunk 81/104: আল্লাহ...
# [GPU 0] Chunk 83/104: আমি আবার কোথায় যাব আমি আমার বাসায় যামু আপু বাসায় তো কেউ নাই এত কথা বলিস না যা...
# [GPU 0] Chunk 85/104: ভাইয়া খাসির মাংস পাঠাইছে একটু খাও দেখা অনেক মজা হইছে হ্যাঁ হাসির মাংসকে একটু খু...
# [GPU 0] Chunk 87/104: বাবা মা আমি তোমাদের সন্তানদের সাথে আর থাকতে পারছি না আমাকে তোমরা ক্ষমা করে দিও ব...
# [GPU 0] Chunk 89/104: আসার পর থেকেই কান্না করতেছো আমাকে তোমার পছন্দ হয়নি আমার আপুর তো আমি ছাড়া আর কে...
# [GPU 0] Chunk 91/104: এই বাসায় নিয়ে আসবো হ্যাঁ যে বোন নিজে বউ সংসার না করে মাতৃস্নেহে তার ভাই বোনদের...
# [GPU 0] Chunk 93/104: ভাইয়া ফারুক কই আপু তো আপুর রুমে আছে না আপু রুমে নাই আরে বাবা আছে কোথাও না কথাও ...
# [GPU 0] Chunk 95/104: যেন আমার উপর আসে তোদেরকে আল্লাহ যেন সারাজীবন ভালো রাখে তোমাদের জন্য শুধুমাত্র তো...
# [GPU 1] Chunk 82/104: রাকিব আমার এই এতিম মনটাকে আমি তোমার হাতে তুলে দিলাম তুমি রাইসাকে কষ্ট দিও না সার...
# [GPU 1] Chunk 84/104: এক দুই তিন ঢাকায় জমি জিতে নিন একশত পার্সেন্ট ক্যাশব্যাক সহ বিশ কোটি টাকার পুরস্...
# [GPU 1] Chunk 86/104: তোমার সন্তানরা আজ কত সুখে আছে আচ্ছা শোনো ভেবেছি সম্পূর্ণ বাসায় আইছি লাগাবো কি ব...
# [GPU 1] Chunk 88/104: তাদের কোন প্রয়োজন নেই তাই চলে যাচ্ছি কি...
# [GPU 1] Chunk 90/104: সে আপুকে নাকি ভাইয়া বলছে আমাদের বাড়ি কাজের বোয়া কি বলতেছো এসব আমি ঠিকই বলছি আ...
# [GPU 1] Chunk 92/104: আপু পারো আপু আপু পারো আপু কি হচ্ছে এসব আপু কোথায় আপুর কই যাবে আপনি কোথাও পাচ্ছি...
# [GPU 1] Chunk 94/104: ছোটবেলায় মা মারা যায় তার কিছুদিন পর মারা যায় বাবা বাবাকে কথা দিয়েছিলাম তোদের...
# [GPU 1] Chunk 96/104: রাইসান চলো এখানে আর এক মুহূর্ত না আমরা আব্বুকে বুঝে বের...
# [GPU 0] Chunk 97/104: কোথায় সবাই এদিকে আসো দেখো আজকে আমাদের অফিসে একজন নতুন অতিথি এসেছেন স্যার নতুন অ...
# [GPU 0] Chunk 99/104: কি বলছেন এসব শেষ পর্যন্ত আপনি আমার বাসার কাজের বোয়াকে বিয়ে করেছেন যে বোনটা ছোট...
# [GPU 0] Chunk 101/104: পারুল আমার ওয়াইফ আজ থেকে পারুল এই অফিসের এমডির চেয়ারে বসবে আর আশা করব আপনারা স...
# [GPU 0] Chunk 103/104: কিভাবেই চান...
# [GPU 1] Chunk 98/104: তুমি আসো এ হচ্ছে আমাদের অফিসের নতুন অতিথি স্যার এটা তো আমাদের পারুল আপা উনি আমাদ...
# [GPU 1] Chunk 100/104: কখনো চাপা থাকে না মিথ্যার রাজত্ব যতদিনই কায়েম থাকুক না কেন সত্য একদিন না একদিন ...
# [GPU 1] Chunk 102/104: আপনি পেজ রিপোর্টকে মাফ করে দেন দেখলেন তো কেমন মানুষকে জীবন সঙ্গিনী করে এনেছি ক্ষ...
# [GPU 1] Chunk 104/104: সেখানে...
#    ✓ Done in 46s  |  speed 55.69× realtime  |  19782 chars
#
# ✅ 24 file(s) processed in 25m 37s
#    Output → /kaggle/working/transcriptions_ct2.csv
#
# =================================================================
# 🏁  CT2 INFERENCE COMPLETE
#     Total time : 25m 37s
# =================================================================

# %% [markdown]
# # RESULTS PREVIEW

# %%
if not df_results.empty:
    print(f"\n{'FILE':<40} {'CHARS':>6}  PREVIEW")
    print("─" * 90)
    for _, row in df_results.iterrows():
        preview = str(row["transcript"])[:80].replace("\n", " ")
        print(f"  {row['filename']:<38} {len(str(row['transcript'])):>6}  {preview}…")
    print(f"\n✨ Results saved → {OUTPUT_CSV}")
else:
    print("⚠️  No results to display.")
# Out:
# FILE                                      CHARS  PREVIEW
# ──────────────────────────────────────────────────────────────────────────────────────────
#   test_001                                19460  হ্যাঁ হ্যাঁ বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে বাইরে তা…
#   test_002                                22367  আমার এই আমি আমি কিন্তু ইচ্ছাধারী নাগিন স্যার নাগ আমি কিন্তু ছমল দিলে তোমরা একদম …
#   test_003                                33897  গল্পটির সত্য আনন্দ পাবলিশারস প্রাইভেট লিমিটেড কর্তৃক সংরক্ষিত তোর নাম কানাই তো ত…
#   test_004                                37913  যেকোনো জায়গায় যেতে রাতের ট্রেনই আমাদের সবচাইতে পছন্দের বেশ খাওয়াদাওয়া সেরে ল…
#   test_005                                28098  মির্চির নিবেদন ফ্রাইডে ক্লাসেক্স ওরে বাবা ওরে বাপ রে বাপ কি মেঘ ডাকছে রে বাবা গ্…
#   test_006                                30741  আপনার মাইয়া আমাদের খুব পছন্দ হইছে আমার ছেলেরে পছন্দ হইছে আমি তাইলে আপনার মেয়ের…
#   test_008                                32524  ভাদ্রের পচা গরম এইরকম মানে নিয়ে রবিবারটা বড্ড অবস্থা ভেঙে খাটে বাজার করা শুরু থ…
#   test_009                                19136  ভাই ভাই ভাই আমারে বাপ কইরো দেন ভাই আমি শিক্ষিত মানুষ ভাই ভাই আমার বাল বাচ্চা আছে…
#   test_010                                17742  ভাই একটু তাড়াতাড়ি করেন আমার ডিভোরেস শুরু হয়ে গেছে অনেক আগেই ডিভোরেসে যাওয়ার …
#   test_011                                35139  মির্চি নিবেদন ফ্রাইডে ক্লাসিক বৈষ্ট্য আনন্দ পাবনাশ্রাস্ত্রের প্রাইভেট বিল্ডিং কর…
#   test_012                                28340  গর্ত তো জেনে আপনাদের সাথে আছি আমি আজ পড়ছিলাম মুহিমুর রহমানের উপন্যাস মধ্যান্য আ…
#   test_013                                16974  লাইফ বয় ভাইরাস ফাইটার যা ভাইরাসের বিরুদ্ধে লড়াই করে আপনাকে রাখবে সুরক্ষিত আর স…
#   test_016                                19613  না তোমার মরিচ বেশি দেন হ্যাঁ আর ওই সরিষাটাই বেশি দেন দেন দেন এটা আমি আছি তুমি আম…
#   test_018                                35392  নমস্কার আমি সৌমেন আর আপনারা শুনছেন গল্পের জন্য ঝুমঝুমিতলার কথা কি না জানে কোঠাইল…
#   test_019                                26848  মিরচির বিশেষ নিবেদন টাইমস অফ পুরান মহামায়া আমি মহাদেবের দূত হয়ে শান্তির বার্তা…
#   test_020                                20861  তোরে ভালোই ভালোই কইতাছি তুই আমার দড়ি খুইলা দে আমি যদি ছুটতে পারি তুই আমার নাক প…
#   test_021                                26616  মিরচির বিশেষ নিবেদন টাইমস অফ পুরান দেবরাজ ইন্দ্রকে রক্ষা করার দায়িত্ব আমার তারক…
#   test_022                                36101  শুনছেন গল্প স্বল্প একশত সাত এফএম রোডে গল্প স্বল্প গল্প স্বল্প গল্পের সব চরিত্র ক…
#   test_023                                30645  শুনছেন গল্প স্বল্প শুধুমাত্র একশত গোমলে প্রিয়নাথ মুখোপাধ্যায়ের জন্ম এক হাজার আ…
#   test_024                                27441  দীর্ঘদিন ধরে খোঁড়াখুঁড়ি করা হচ্ছে তার উপরে আজকে আকাশে প্রায় বৃষ্টি দেখা দিল ব…
#   test_027                                35646  গ্রামের নিঃসন্তান দম্পতি হলো বিশু নির্মলা বিকেল থেকেই আকাশটা মেঘলা হয়ে রয়েছে য…
#   test_029                                20503  তোমার একটু আস্তে আস্তে আপনার লগে হাইটে কি আমি পারি কইলাম একটা ভ্যান নিতে তাও নিল…
#   test_030                                21230  লাইফ বয় ভাইরাস ফাইটার যা ভাইরাসের বিরুদ্ধে লড়াই করে আপনাকে রাখবে সুরক্ষিত আর স…
#   test_032                                19782  রাইসা রাইসা হে আপু বলো একটু এদিকে আয় তো শোন নাস্তা রেডি আছে রিপন রুপকে তুলে সবা…
#
# ✨ Results saved → /kaggle/working/transcriptions_ct2.csv
